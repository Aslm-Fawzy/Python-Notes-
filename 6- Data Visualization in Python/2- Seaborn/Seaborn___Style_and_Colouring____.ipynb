# %% [markdown]
# #**importing Libraries :-**
#
# ---

# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
#allowing your chart to printed in the notebook
# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 8]}, font_scale=1.2)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# #**Catplots :-**

# %%
df_penguins = sns.load_dataset('penguins')

# %%
df_penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.catplot(x='species',data=df_penguins,kind='count')

# %%
sns.catplot(x='species',y='body_mass_g',kind='bar',estimator=np.mean,data=df_penguins,height=7,aspect=1.2)

# %%
sns.catplot(x='species', y="body_mass_g", data=df_penguins ,kind="strip", height=6, aspect=1.3)

# %%
sns.catplot(x='species', y="body_mass_g", data=df_penguins ,kind="violin", height=6, aspect=1.3)

# %%
sns.catplot(x='species', y="body_mass_g", data=df_penguins ,kind="violin", height=6, aspect=1.3,hue='sex',
            split=True)

# %%
sns.catplot(x='species', y="body_mass_g", data=df_penguins ,kind="box", height=6, aspect=1.3)

# %%
sns.catplot(x='species', y="body_mass_g", data=df_penguins ,kind="box", height=6, aspect=1.3,hue='sex')

# %%
df_tips = sns.load_dataset('tips')

# %%
sns.catplot(x="day", y="total_bill", data=df_tips, height=5, aspect=1.2,
            hue="sex", kind="violin", split=True, col="time")

# %%
sns.catplot(x="day", y="total_bill", data=df_tips, height=5, aspect=1.2,
            hue="sex", kind="box", col="time", row="smoker")

# %% [markdown]
# #**Mutiple Type Plots In One  Chart :-**
#
#
# ---

# %%
sns.boxplot(x='species', y="body_mass_g", data=df_penguins)
sns.stripplot(x="species", y="body_mass_g", data=df_penguins,color='k')

# %%
#Loading built-in dataset in seeborn
df_titanic = sns.load_dataset('titanic')
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.boxplot(x='alive', y="age", data=df_titanic)
sns.stripplot(x="alive", y="age", data=df_titanic,color='k')

# %%
sns.violinplot(x='species',y='body_mass_g',data=df_penguins)
sns.stripplot(x='species',y='body_mass_g',data=df_penguins,color='k')

# %% [markdown]
# #**SubPlots :-**
# ---

# %%
fig, axes = plt.subplots(1,2 , figsize= (20,7)) 
fig.suptitle ('2 Plots')
sns.boxplot( ax=axes [0] ,x='species', y="body_mass_g", data=df_penguins,hue='sex')
sns.violinplot(  ax=axes [1]  , x='species', y="body_mass_g", data=df_penguins,hue='sex',split=True )

# %%
fig, axes = plt.subplots(1,3 , figsize= (20,10)) 
fig.suptitle ('3 Plots')
sns.boxplot( ax=axes [0] ,x='alive', y="age", data=df_titanic,hue='sex')
sns.violinplot(  ax=axes [1]  , x='alive', y="age", data=df_titanic,hue='sex',split=True )
sns.barplot( ax=axes [2]  , x='alive', y="age", data=df_titanic,hue='sex' )

# %%
fig, axes = plt.subplots(2,2 , figsize= (20,15)) 
fig.suptitle ('4 Plots')
sns.swarmplot( ax=axes [0][0] ,x= 'sex' , y ='total_bill' , data= df_tips , hue= 'time')
sns.boxplot(  ax=axes [0] [1] , x= 'sex', y='total_bill' , data=df_tips, hue= 'day')
sns.stripplot ( ax = axes [1][0] ,x= 'sex' , y ='total_bill' , data= df_tips )
sns.violinplot( ax = axes [1][1], x= 'sex', y='total_bill' , data=df_tips, hue= 'time' , split= True )

# %%
df = sns.load_dataset('tips')

# %%
fig, axes = plt.subplots(1,2 , figsize= (20,7)) 
fig.suptitle ('Total Bills vs Tips',fontsize=25,color='k',fontweight='bold')
sns.kdeplot(ax=axes [0], data=df['total_bill'],color='b',shade=True,multiple='stack')
sns.kdeplot(ax=axes [1], data=df['tip'],color='b',shade=True,multiple='stack')

# %% [markdown]
# #**Palettes :-**
#
# > we can apply coloured plalettes in any data type (numerical and categroical)

# %% [markdown]
# you can Check out the documentation page for more info on these topics: https://seaborn.pydata.org/tutorial/color_palettes.html
#
# **Possible values are**
# * Accent
# * Accent_r
# * Blues
# * Blues_r
# * BrBG
# * BrBG_r
# * BuGn
# * BuGn_r
# * BuPu
# * BuPu_r
# * CMRmap
# * CMRmap_r
# * Dark2
# * Dark2_r
# * GnBu
# * GnBu_r
# * Greens
# * Greens_r
# * Greys
# * Greys_r
# * OrRd
# * OrRd_r
# * Oranges
# * Oranges_r
# * PRGn
# * PRGn_r
# * Paired
# * Paired_r
# * Pastel1
# * Pastel1_r
# * Pastel2
# * Pastel2_r
# * PiYG
# * PiYG_r
# * PuBu
# * PuBuGn
# * PuBuGn_r
# * PuBu_r
# * PuOr
# * PuOr_r
# * PuRd
# * PuRd_r
# * Purples
# * Purples_r
# * RdBu
# * RdBu_r
# * RdGy
# * RdGy_r
# * RdPu
# * RdPu_r
# * RdYlBu
# * RdYlBu_r
# * RdYlGn
# * RdYlGn_r
# * Reds
# * Reds_r
# * Set1
# * Set1_r
# * Set2
# * Set2_r
# * Set3
# * Set3_r
# * Spectral
# * Spectral_r
# * Wistia
# * Wistia_r
# * YlGn
# * YlGnBu
# * YlGnBu_r
# * YlGn_r
# * YlOrBr
# * YlOrBr_r
# * YlOrRd
# * YlOrRd_r
# * afmhot
# * afmhot_r
# * autumn
# * autumn_r
# * binary
# * binary_r
# * bone
# * bone_r
# * brg
# * brg_r
# * bwr
# * bwr_r
# * cividis
# * cividis_r
# * cool
# * cool_r
# * coolwarm
# * coolwarm_r
# * copper
# * copper_r
# * cubehelix
# * cubehelix_r
# * flag
# * flag_r
# * gist_earth
# * gist_earth_r
# * gist_gray
# * gist_gray_r
# * gist_heat
# * gist_heat_r
# * gist_ncar
# * gist_ncar_r
# * gist_rainbow
# * gist_rainbow_r
# * gist_stern
# * gist_stern_r
# * gist_yarg
# * gist_yarg_r
# * gnuplot
# * gnuplot2
# * gnuplot2_r
# * gnuplot_r
# * gray
# * gray_r
# * hot
# * hot_r
# * hsv
# * hsv_r
# * icefire
# * icefire_r
# * inferno
# * inferno_r
# * jet
# * jet_r
# * magma
# * magma_r
# * mako
# * mako_r
# * nipy_spectral
# * nipy_spectral_r
# * ocean
# * ocean_r
# * pink
# * pink_r
# * plasma
# * plasma_r
# * prism
# * prism_r
# * rainbow
# * rainbow_r
# * rocket
# * rocket_r
# * seismic
# * seismic_r
# * spring
# * spring_r
# * summer
# * summer_r
# * tab10
# * tab10_r
# * tab20
# * tab20_r
# * tab20b
# * tab20b_r
# * tab20c
# * tab20c_r
# * terrain
# * terrain_r
# * twilight
# * twilight_r
# * twilight_shifted
# * twilight_shifted_r
# * viridis
# * viridis_r
# * vlag
# * vlag_r
# * winter
# * winter_r

# %%
sns.barplot(x='alone',y='survived',estimator=np.sum,data=df_titanic,palette='blues')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     205                 # Perhaps a named matplotlib colormap?
# --> 206                 palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207             except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/seaborn/palettes.py in mpl_palette(name, n_colors, as_cmap)
#     442     else:
# --> 443         cmap = mpl.cm.get_cmap(name)
#     444
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cm.py in get_cmap(name, lut)
#     133         return name
# --> 134     cbook._check_in_list(sorted(cmap_d), name=name)
#     135     if lut is None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in _check_in_list(_values, **kwargs)
# ...

# %%
sns.barplot(x='alone',y='survived',estimator=np.sum,data=df_titanic,palette='mako')

# %%
sns.barplot(x='alone',y='survived',estimator=np.sum,data=df_titanic,palette='viridis')

# %%
sns.countplot(palette='Blues',x='class',data=df_titanic)

# %%
sns.countplot(palette='Oranges',x='embark_town',data=df_titanic)

# %%
sns.barplot(x='alive',y='age',data=df_titanic,palette='rocket')

# %%
sns.barplot(x='class',y='survived',data=df_titanic,palette='rocket',estimator=np.sum)

# %%
sns.countplot(x='alive',data=df_titanic,palette='gist_earth',hue='who')

# %% [markdown]
# #**HeatMap :-**

# %%
df_titanic['new'] = df_titanic['sibsp']+df_titanic['parch']

# %%
df_titanic.corr()
# Out:
#             survived    pclass       age  ...  adult_male     alone       new
# survived    1.000000 -0.338481 -0.077221  ...   -0.557080 -0.203367  0.016639
# pclass     -0.338481  1.000000 -0.369226  ...    0.094035  0.135207  0.065997
# age        -0.077221 -0.369226  1.000000  ...    0.280328  0.198270 -0.301914
# sibsp      -0.035322  0.083081 -0.308247  ...   -0.253586 -0.584471  0.890712
# parch       0.081629  0.018443 -0.189119  ...   -0.349943 -0.583398  0.783111
# fare        0.257307 -0.549500  0.096067  ...   -0.182024 -0.271832  0.217138
# adult_male -0.557080  0.094035  0.280328  ...    1.000000  0.404744 -0.348143
# alone      -0.203367  0.135207  0.198270  ...    0.404744  1.000000 -0.690922
# new         0.016639  0.065997 -0.301914  ...   -0.348143 -0.690922  1.000000
#
# [9 rows x 9 columns]

# %%
sns.heatmap(df_titanic.corr())

# %%
sns.heatmap(df_titanic[['age','survived']].corr(),cmap='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-0d32933481ad> in <module>()
# ----> 1 sns.heatmap(df_titanic[['age','survived']].corr(),cmap='')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
sns.heatmap(df_titanic[['pclass','survived','new','age']].corr(),cmap='Blues_r',annot=True)

# %%
sns.heatmap(df_titanic[['pclass','survived','new','age']].corr(),cmap='Blues_r', annot=True,linecolor='y',linewidths=2)

# %%
df_flights = sns.load_dataset('flights')
df_flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df_flights = df_flights.pivot_table(values='passengers', index='month', columns='year')

# %%
sns.heatmap(df_flights.corr(), linecolor='k', linewidths=2,cmap='CMRmap')
