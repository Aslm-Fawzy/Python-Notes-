# %% [markdown]
# # **Web Scraping**
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites. Web scraping software may directly access the World Wide Web using the Hypertext Transfer Protocol or a web browser.
#
# Web scraping can be done manually by a software user, the term typically refers to automated processes implemented using a bot or web crawler. It is a form of copying in which specific data is gathered and copied from the web, typically into a central local database or spreadsheet, for later retrieval or analysis.
#
#  Most Popular Python Scraping Tools is BeatifulSoup , Scrapy and Selenium
#
#  I've used BeatifulSoup and Selenium in this notebook

# %% [markdown]
# ## **BeautifulSoup Library**
# Beautiful Soup is a Python library for parsing structured data. It allows you to interact with HTML in a similar way to how you interact with a web page using developer tools. The library exposes a couple of intuitive functions you can use to explore the HTML you received.
#
# **For More Information :** https://realpython.com/beautiful-soup-web-scraper-python/#:~:text=Beautiful%20Soup%20is%20a%20Python%20library%20for%20parsing,started%2C%20use%20your%20terminal%20to%20install%20Beautiful%20Soup%3A

# %%
# pip install beautifulsoup4

# %% [markdown]
# ### 1. Intro to Scraping
# ------------------------------
# > Frsit Scraping example and Try to scrap data from : https://jekso.github.io/scrapping-example/index.html

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
response = requests.get('https://jekso.github.io/scrapping-example/index.html')
print(response.text)
# Out:
# <!DOCTYPE html>
#
# <html>
#
#     <head>
#         <title>My First HTML Page</title>
#
#         <style>
#
#             p {
#                 color: green;
#
#             }
#
#             h1 {
#                 color:blue;
#                 text-shadow: 2px 2px 5px red;
#             }
#
#
#             img {
#                 width: 200px;
#                 height: 200px;
#             }
#
#
#             select {
#                 width: 300px;
#                 height: 50px;
#                 background-color: orange;
#             }
#
#             div#bigred {
#                 width: 100%%;
#                 height: 200px;
#                 background-color: red;
#                 margin: 20px;
#                 color: white;
#             }
#
#
#             div#smallblue {
#                 width: 100%%;
#                 height: 100px;
#                 background-color: blue;
#                 margin: 20px;
#                 color: yellow;
#             }
#
#             li.redul {
#                 color: red;
#             }
#
#             li.blueol {
#                 color:blue;
#             }
#
#             .h2_orange {
#                 color: orange;
#             }
#
#             .jupyter_img {
#                 width: 200px;
#                 height: 200px;
#                 border: solid green 3px;
#             }
#
#             .bg-yellow {
#                 background-color: yellow;
#             }
#
#         </style>
#
#     </head>
#
#
#     <body>
#
#         <p>Iam a paragrapph</p>
#
#         <br><hr><br>
#
#         <h1>My First H1 Header</h1>
#         <h1>My Second H1 Header</h1>
#
#         <h2 class="h2_orange bg-yellow">My First H2 Header</h2>
#         <h2 class="h2_orange">My Second H2 Header</h2>
#         <h2>My 3rd H2 Header</h2>
#
#
#         <br><hr><br>
#
#         <ul>
#             <li class='redul'> Milk </li>
#             <li class='redul'> Oranges </li>
#         </ul>
#
#         <br><hr><br>
#
#         <ol>
#             <li class='blueol'> Milk </li>
#             <li class='blueol'> Oranges </li>
#         </ol>
#
#         <br><hr><br>
#
#         <img src="my_img.png" class="jupyter_img">
#
#         <br><hr><br>
#
#         <a href="http://www.google.com">Go To Google</a>
#
#         <br><hr><br>
#
#         <form>
#             Username: <input type="text" class="bg-yellow">
#             <br><br>
#             Passowrd: <input type="password">
#             <br><br>
#
#             <select>
#                 <option value="volvo">Volvo</option>
#                 <option value="saab">Saab</option>
#                 <option value="fiat">Fiat</option>
#                 <option value="audi">Audi</option>
#             </select>
#             <br><br>
#
#             <input type="checkbox">
#             I agree for the terms
#             <br><br>
#
#             <input type="submit" value="Search">
#         </form>
#
#         <br><hr><br>
#
#         <table>
#             <tr>
#                 <th>House Size</th>
#                 <th>Num of Rooms</th>
#                 <th class="bg-yellow">Has Garden</th>
#                 <th>Price</th>
#             </tr>
#             <tr>
#                 <td>120</td>
#                 <td>3</td>
#                 <td>yes</td>
#                 <td>500000</td>
#             </tr>
#             <tr>
#                 <td>140</td>
#                 <td>4</td>
#                 <td class="bg-yellow">no</td>
#                 <td>750000</td>
#             </tr>
#             <tr>
#                 <td>80</td>
#                 <td>1</td>
#                 <td>no</td>
#                 <td>300000</td>
#             </tr>
#         </table>
#
#
#         <br><hr><br>
#
#
#
#
#         <iframe width="420" height="345" src="https://www.youtube.com/embed/tgbNymZ7vqY"></iframe>
#
#
#         <br><hr><br>
#
#
#         <div id='bigred'>
#             Hello world
#         </div>
#
#         <br><hr><br>
#
#
#         <div id="smallblue">
#             Hello python
#             <p>Iam a paragrapph</p>
#         </div>
#
#
#
#
#     </body>
#
#
# </html>

# %%
type(response.text)
# Out:
# str

# %%
soup = BeautifulSoup(response.text, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>My First HTML Page</title>
# <style>
#
#             p {
#                 color: green;
#
#             }
#
#             h1 {
#                 color:blue;
#                 text-shadow: 2px 2px 5px red;
#             }
#
#
#             img {
#                 width: 200px;
#                 height: 200px;
#             }
#
#
#             select {
#                 width: 300px;
#                 height: 50px;
#                 background-color: orange;
#             }
#
#             div#bigred {
#                 width: 100%%;
#                 height: 200px;
#                 background-color: red;
#                 margin: 20px;
#                 color: white;
#             }
#
#
#             div#smallblue {
#                 width: 100%%;
#                 height: 100px;
#                 background-color: blue;
#                 margin: 20px;
#                 color: yellow;
#             }
#
#             li.redul {
#                 color: red;
#             }
#
#             li.blueol {
#                 color:blue;
#             }
#
#             .h2_orange {
#                 color: orange;
#             }
#
#             .jupyter_img {
#                 width: 200px;
#                 height: 200px;
#                 border: solid green 3px;
#             }
#
#             .bg-yellow {
#                 background-color: yellow;
#             }
#
#         </style>
# </head>
# <body>
# <p>Iam a paragrapph</p>
# <br/><hr/><br/>
# <h1>My First H1 Header</h1>
# <h1>My Second H1 Header</h1>
# <h2 class="h2_orange bg-yellow">My First H2 Header</h2>
# <h2 class="h2_orange">My Second H2 Header</h2>
# <h2>My 3rd H2 Header</h2>
# <br/><hr/><br/>
# <ul>
# <li class="redul"> Milk </li>
# <li class="redul"> Oranges </li>
# </ul>
# <br/><hr/><br/>
# <ol>
# <li class="blueol"> Milk </li>
# <li class="blueol"> Oranges </li>
# </ol>
# <br/><hr/><br/>
# <img class="jupyter_img" src="my_img.png"/>
# <br/><hr/><br/>
# <a href="http://www.google.com">Go To Google</a>
# <br/><hr/><br/>
# <form>
#             Username: <input class="bg-yellow" type="text"/>
# <br/><br/>
#             Passowrd: <input type="password"/>
# <br/><br/>
# <select>
# <option value="volvo">Volvo</option>
# <option value="saab">Saab</option>
# <option value="fiat">Fiat</option>
# <option value="audi">Audi</option>
# </select>
# <br/><br/>
# <input type="checkbox"/>
#             I agree for the terms
#             <br/><br/>
# <input type="submit" value="Search"/>
# </form>
# <br/><hr/><br/>
# <table>
# <tr>
# <th>House Size</th>
# <th>Num of Rooms</th>
# <th class="bg-yellow">Has Garden</th>
# <th>Price</th>
# </tr>
# <tr>
# <td>120</td>
# <td>3</td>
# <td>yes</td>
# <td>500000</td>
# </tr>
# <tr>
# <td>140</td>
# <td>4</td>
# <td class="bg-yellow">no</td>
# <td>750000</td>
# </tr>
# <tr>
# <td>80</td>
# <td>1</td>
# <td>no</td>
# <td>300000</td>
# </tr>
# </table>
# <br/><hr/><br/>
# <iframe height="345" src="https://www.youtube.com/embed/tgbNymZ7vqY" width="420"></iframe>
# <br/><hr/><br/>
# <div id="bigred">
#             Hello world
#         </div>
# <br/><hr/><br/>
# <div id="smallblue">
#             Hello python
#             <p>Iam a paragrapph</p>
# </div>
# </body>
# </html>

# %%
title = soup.find('title')
title
# Out:
# <title>My First HTML Page</title>

# %%
page = title.get_text().strip()
page
# Out:
# 'My First HTML Page'

# %%
paragraphs = soup.find_all('p')
paragraphs
# Out:
# [<p>Iam a paragrapph</p>, <p>Iam a paragrapph</p>]

# %%
for p in paragraphs :
    print(p.get_text())
    print('----' *5)
# Out:
# Iam a paragrapph
# --------------------
# Iam a paragrapph
# --------------------

# %%
heads_2 = soup.find_all('h2')
heads_2
# Out:
# [<h2 class="h2_orange bg-yellow">My First H2 Header</h2>,
#  <h2 class="h2_orange">My Second H2 Header</h2>,
#  <h2>My 3rd H2 Header</h2>]

# %%
h2_orange = soup.find_all('h2' , attrs={'class': 'h2_orange'})
print(h2_orange)
# Out:
# [<h2 class="h2_orange bg-yellow">My First H2 Header</h2>, <h2 class="h2_orange">My Second H2 Header</h2>]

# %%
for h2 in h2_orange :
    print(h2.get_text())
    print(h2.attrs)
    print('----'*5)
# Out:
# My First H2 Header
# {'class': ['h2_orange', 'bg-yellow']}
# --------------------
# My Second H2 Header
# {'class': ['h2_orange']}
# --------------------

# %%
for h2 in h2_orange :
    print(h2.get_text())
    print(h2.get('class'))
    print('----'*5)
# Out:
# My First H2 Header
# ['h2_orange', 'bg-yellow']
# --------------------
# My Second H2 Header
# ['h2_orange']
# --------------------

# %%
for h2 in h2_orange :
    print(h2.get_text())
    print(h2.name)
    print('----'*5)
# Out:
# My First H2 Header
# h2
# --------------------
# My Second H2 Header
# h2
# --------------------

# %%
h2_bg_yellow = soup.find_all('h2' , attrs={'class': 'bg-yellow'})
h2_bg_yellow
# Out:
# [<h2 class="h2_orange bg-yellow">My First H2 Header</h2>]

# %%
h2_bg_yellow[0].get_text()
# Out:
# 'My First H2 Header'

# %%
h2_bg_yellow[0].attrs
# Out:
# {'class': ['h2_orange', 'bg-yellow']}

# %%
h2_bg_yellow[0].attrs['class']
# Out:
# ['h2_orange', 'bg-yellow']

# %%
h2_bg_yellow[0].has_attr('class')
# Out:
# True

# %%
h2_bg_yellow[0].get('class')
# Out:
# ['h2_orange', 'bg-yellow']

# %%
h2_bg_yellow[0].attrs['class'][1]
# Out:
# 'bg-yellow'

# %%
h2_bg_yellow[0].get('id')

# %%
h2_bg_yellow[0].has_attr('id')
# Out:
# False

# %%
all_link = soup.find_all('a')
all_link
# Out:
# [<a href="http://www.google.com">Go To Google</a>]

# %%
for a in all_link :
    print(a.get_text())
    print(a.get('href'))
# Out:
# Go To Google
# http://www.google.com

# %%
form = soup.find_all('form')
form
# Out:
# [<form>
#              Username: <input class="bg-yellow" type="text"/>
#  <br/><br/>
#              Passowrd: <input type="password"/>
#  <br/><br/>
#  <select>
#  <option value="volvo">Volvo</option>
#  <option value="saab">Saab</option>
#  <option value="fiat">Fiat</option>
#  <option value="audi">Audi</option>
#  </select>
#  <br/><br/>
#  <input type="checkbox"/>
#              I agree for the terms
#              <br/><br/>
#  <input type="submit" value="Search"/>
#  </form>]

# %%
for option in form[0].find_all('option'):
    print(option.get_text().strip())
# Out:
# Volvo
# Saab
# Fiat
# Audi

# %%
for op in form[0].find_all('option'):
    print(op.get('value'))
# Out:
# volvo
# saab
# fiat
# audi

# %%
all_divs = soup.find_all('div')
all_divs
# Out:
# [<div id="bigred">
#              Hello world
#          </div>,
#  <div id="smallblue">
#              Hello python
#              <p>Iam a paragrapph</p>
#  </div>]

# %%
for div in all_divs :
    print(div.get_text().strip())
# Out:
# Hello world
# Hello python
#             Iam a paragrapph

# %%
for div in all_divs :
    for p in div.find_all('p') :
        print(p.get_text())
# Out:
# Iam a paragrapph

# %%
for div in all_divs :
    print(div.get('id'))
    print('-----')
# Out:
# bigred
# -----
# smallblue
# -----

# %%
iframe  = soup.find('iframe')
iframe
# Out:
# <iframe height="345" src="https://www.youtube.com/embed/tgbNymZ7vqY" width="420"></iframe>

# %%
iframe.attrs
# Out:
# {'width': '420',
#  'height': '345',
#  'src': 'https://www.youtube.com/embed/tgbNymZ7vqY'}

# %%
iframe.attrs['width']
# Out:
# '420'

# %%
iframe.attrs['class']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-a823b93cb01b> in <module>
# ----> 1 iframe.attrs['class']
#
# KeyError: 'class'

# %%
iframe.get('width')
# Out:
# '420'

# %%
iframe.get('class')

# %%
width = int(iframe.get('width'))
height = int(iframe.get('height'))
resolution = width * height
resolution
# Out:
# 144900

# %%
link = iframe.get('src').strip()
link
# Out:
# 'https://www.youtube.com/embed/tgbNymZ7vqY'

# %%
table = soup.find_all('tr')
table
# Out:
# [<tr>
#  <th>House Size</th>
#  <th>Num of Rooms</th>
#  <th class="bg-yellow">Has Garden</th>
#  <th>Price</th>
#  </tr>,
#  <tr>
#  <td>120</td>
#  <td>3</td>
#  <td>yes</td>
#  <td>500000</td>
#  </tr>,
#  <tr>
#  <td>140</td>
#  <td>4</td>
#  <td class="bg-yellow">no</td>
#  <td>750000</td>
#  </tr>,
#  <tr>
#  <td>80</td>
#  <td>1</td>
#  <td>no</td>
#  <td>300000</td>
#  </tr>]

# %%
for row in table :
    print(row)
    print('-----------' + '\n\n')
# Out:
# <tr>
# <th>House Size</th>
# <th>Num of Rooms</th>
# <th class="bg-yellow">Has Garden</th>
# <th>Price</th>
# </tr>
# -----------
#
#
# <tr>
# <td>120</td>
# <td>3</td>
# <td>yes</td>
# <td>500000</td>
# </tr>
# -----------
#
#
# <tr>
# <td>140</td>
# <td>4</td>
# <td class="bg-yellow">no</td>
# <td>750000</td>
# </tr>
# -----------
#
#
# <tr>
# <td>80</td>
# <td>1</td>
# <td>no</td>
# <td>300000</td>
# </tr>
# -----------

# %%
for head in soup.find_all('th') :
    print(head.get_text())
    print('----')
# Out:
# House Size
# ----
# Num of Rooms
# ----
# Has Garden
# ----
# Price
# ----

# %%
header = [head.get_text() for head in soup.find_all('th') ]
header
# Out:
# ['House Size', 'Num of Rooms', 'Has Garden', 'Price']

# %%
for td in soup.find_all('td') :
    print(td.get_text())
# Out:
# 120
# 3
# yes
# 500000
# 140
# 4
# no
# 750000
# 80
# 1
# no
# 300000

# %%
all_rows = []
for tr in soup.find_all('tr')[1:]:
    row = [ td.get_text() for td in tr.find_all('td')]
    all_rows.append(row)
print(all_rows)
# Out:
# [['120', '3', 'yes', '500000'], ['140', '4', 'no', '750000'], ['80', '1', 'no', '300000']]

# %%
all_rows = []
for tr in soup.find_all('tr')[1:]:
    row = []
    for td in tr.find_all('td') : 
         row.append(td.get_text())
    all_rows.append(row)
print(all_rows)
# Out:
# [['120', '3', 'yes', '500000'], ['140', '4', 'no', '750000'], ['80', '1', 'no', '300000']]

# %%
for row in range(len(all_rows)) :
    print('Row Number', row+1 ,':', all_rows[row])
# Out:
# Row Number 1 : ['120', '3', 'yes', '500000']
# Row Number 2 : ['140', '4', 'no', '750000']
# Row Number 3 : ['80', '1', 'no', '300000']

# %%
with open('data.csv', mode='w') as employee_file:
    writer = csv.writer(employee_file)
    
    header = [ th.get_text() for th in soup.find_all('th')]
    writer.writerow(header)
    
    for tr in soup.find_all('tr')[1:]:
        row = [ td.get_text() for td in tr.find_all('td')]
        writer.writerow(row)

# %% [markdown]
# ### 2. USD To EGP Exchange
#
# Scrap the USD To EGP Exchange rate from this website
# https://www.exchangerates.org.uk/Dollars-to-Egyptian-Pounds-currency-conversion-page.html
# and then use it to make a software that takes amount of USD Dollars from the user and calculate how much will it cost in EGP.

# %%
response = requests.get('https://www.exchangerates.org.uk/Dollars-to-Egyptian-Pounds-currency-conversion-page.html')
soup = BeautifulSoup(response.text, 'html.parser')

# %%
div = soup.find_all('div' , {'class':'p_conv30'})
div
# Out:
# [<div class="p_conv30">
#  <p>Welcome to the <b>Dollars to Egyptian Pounds</b> page, updated every minute between Sunday 22:00 and Friday 22:00 (UK)</p>
#  </div>,
#  <div class="p_conv30">
#  <span id="shd2a">1 USD = <span id="shd2b;">18.9174</span> EGP</span>
#  </div>]

# %%
title  = div[0].find('p').get_text().split('page')[0] 
title
# Out:
# 'Welcome to the Dollars to Egyptian Pounds '

# %%
USD_to_EGP =  float(div[1].find('span',{'id' :'shd2b;'}).get_text())
USD_to_EGP
# Out:
# 18.9174

# %%
print(title)
print('--'*40)
USD = int(input('Enter USD Dollars : '))
EGP = USD * USD_to_EGP
print(f'{USD} USD =  {EGP} EGP ')
# Out:
# Welcome to the Dollars to Egyptian Pounds
# --------------------------------------------------------------------------------
# Enter USD Dollars : 4
# 4 USD =  75.6696 EGP

# %% [markdown]
# ### 3. Scraping MIT Algorithm Course
# -----------------------------------------------------
# > Scraping lectures videos links for introduction to algorithm course from MIT University and saving lecture name and its  video link in csv file(introduction to algorithm.csv).
#
# > Scraping Link : https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-006-introduction-to-algorithms-spring-2020/lecture-videos/#

# %%
response = requests.get('https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-006-introduction-to-algorithms-spring-2020/lecture-videos/#')
print(response.text)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#   <link href="/static/css/course.80259.css" rel="stylesheet">
#
#
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NMQZ25T');</script>
#
#
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover">
#
#   <meta name="description" content="MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity">
#   <meta name="keywords" content="opencourseware,MIT OCW,courseware,MIT opencourseware,Free Courses,class notes,class syllabus,class materials,tutorials,online courses,MIT courses">
#   <link rel="canonical" href="https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-videos/" />
#
#   <script type="application/ld+json">
#       {
#         "@context": "http://schema.org/",
#         "@type" : "WebPage",
#         "name": "MIT OpenCourseWare",
#         "description": "MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity",
#         "license": "http://creativecommons.org/licenses/by-nc-sa/4.0/",
#         "publisher": {
#           "@type": "CollegeOrUniversity",
#           "name": "MIT OpenCourseWare"
#         }
#       }
#   </script>
#
#
# <title>Lecture Videos | Introduction to Algorithms | Electrical Engineering and Computer Science | MIT OpenCourseWare</title>
#
#
#   <link href="/static/css/main.80259.css" rel="stylesheet">
#   <link href="https://fonts.googleapis.com/css?family=Roboto:400,500&display=swap" rel="stylesheet">
#   <style>
#   @font-face {
#     font-family: 'Material Icons';
#     font-style: normal;
#     font-weight: 400;
#     src: local('Material Icons'),
#       local('MaterialIcons-Regular'),
#       url(/static/fonts/MaterialIcons-Regular.woff2) format('woff2'),
#       url(/static/fonts/MaterialIcons-Regular.woff) format('woff'),
#       url(/static/fonts/MaterialIcons-Regular.ttf) format('truetype');
#   }
#   @font-face {
#     font-family: 'Material Icons Round';
#     font-style: normal;
#     font-weight: 400;
#     src: local("MaterialIcons-Round"),
#     url(/static/fonts/MaterialIconsRound-Regular.woff2) format('woff2');
#   }
#   @font-face {
#     font-family: 'Cardo Bold';
#     font-style: normal;
#     font-weight: bold;
#     src: local('Cardo'),
#       local('Cardo-Bold'),
#       url(/static/fonts/Cardo-Bold.ttf) format('truetype');
#   }
#   @font-face {
#     font-family: 'Cardo Italic';
#     font-style: italic;
#     font-weight: 400;
#     src: local('Cardo'),
#       local('Cardo-Italic'),
#       url(/static/fonts/Cardo-Italic.ttf) format('truetype');
#   }
#   @font-face {
#     font-family: 'Helvetica Light';
#     font-style: normal`;
#     font-weight: 400;
#     src: local('Helvetica Light'),
#       local('Helvetica-Light'),
#       url(/static/fonts/Helvetica-Light.ttf) format('truetype');
#   }
#   </style>
# </head>
#
# <body class="course-home-page">
#
#
#     <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NMQZ25T"
#     height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
#
#   <div class="overflow-auto">
#     <div
#   id="mobile-course-nav"
#   class="navbar-offcanvas medium-and-below-only nav-drawer">
#   <h5 class="text-uppercase mb-4 mt-4">Browse Course Material</h5>
#
# <nav id="course-nav" class="course-nav">
#   <ul class="w-100 m-auto list-unstyled">
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/syllabus">
#         Syllabus
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_806697d9-a77b-cfb5-791d-be64ae934dc9">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/calendar">
#         Calendar
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_7d2ea4af-b24a-df20-2423-9a0889bc50ab">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/video_galleries/lecture-videos">
#         Lecture Videos
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_2dd8a6bf-697c-cc23-b282-ae6f9dec5b6f">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/lecture-notes">
#         Lecture Notes
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_51ba9637-0a92-32f2-88ab-0bef851c9ad4">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/quizzes">
#         Quizzes
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_400e6a8d-35c4-e497-f645-fe19629c58f3">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/practice-problems">
#         Practice Problems
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_60da50f1-00f1-a813-476b-6e6a65e98226">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/assignments">
#         Assignments
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_bdb6c046-d849-dd11-ab64-cdea4975d145">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/resource-index">
#         Resource Index
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_d8f3bab7-a81a-a2de-20cc-c78674a64694">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#   </ul>
# </nav>
#
# </div>
#
#     <div
#   id="course-info-drawer"
#   class="bg-faded pt-3 bg-light navbar-offcanvas navbar-offcanvas-right medium-and-below-only nav-drawer"
# >
#
#
# <div class="table-responsive course-info">
#   <div class="course-info-expander">
#     <h4 class="course-info-title font-weight-bold">Course Info</h4>
#   </div>
#   <div id="course-info" class="position-relative " aria-expanded="false">
#     <table id="course-info-table" class="table table-borderless mb-0" >
#
#       <tr>
#
#         <td class="pl-0">Instructors:</td>
#         <td>
#
#
#
#
#
# <ul class="list-unstyled m-0">
#
#
#
#
#
#   <li>
#
#     <a href="/search?q=Prof.&#43;Erik&#43;Demaine" class="course-info-instructor">
#       Prof. Erik Demaine
#     </a>
#
#   </li>
#
#
#
#
#
#   <li>
#
#     <a href="/search?q=Dr.&#43;Jason&#43;Ku" class="course-info-instructor">
#       Dr. Jason Ku
#     </a>
#
#   </li>
#
#
#
#
#
#   <li>
#
#     <a href="/search?q=Prof.&#43;Justin&#43;Solomon" class="course-info-instructor">
#       Prof. Justin Solomon
#     </a>
#
#   </li>
#
# </ul>
#
#
#         </td>
#       </tr>
#
#       <tr>
#         <td class="pl-0">Course Number:</td>
#         <td>
#
#
#
#
# <ul class="list-unstyled m-0">
#
#
#
#
#
#   <li>
#
#     6.006
#
#   </li>
#
#
#
#
#
#   <li>
#
#
#
#   </li>
#
# </ul>
#
# </td>
#       </tr>
#
#       <tr>
#         <td class="pl-0">Departments:</td>
#         <td>
#
#
#
#
#
#
# <ul class="list-unstyled m-0">
#
#
#
#
#
#   <li>
#
#     <a href="/search?d=Electrical&#43;Engineering&#43;and&#43;Computer&#43;Science" class="course-info-department">
#       Electrical Engineering and Computer Science
#     </a>
#
#   </li>
#
# </ul>
#
#
#         </td>
#       </tr>
#
#
#       <tr>
#         <td class="pl-0 text-nowrap">As Taught In:</td>
#         <td>
#           Spring 2020
#         </td>
#       </tr>
#       <tr>
#         <td class="pl-0">Level:</td>
#         <td>
#
#
#
#               <a href="/search?l=Undergraduate" class="course-info-level">
#                 Undergraduate
#               </a><br />
#
#
#         </td>
#       </tr>
#     </table>
#   </div>
# </div>
# <div class="border-top-gray ">
#
# </div>
#
#
#
#
# <div class="border-bottom-gray my-2">
#   <h4 class="course-info-title font-weight-bold">Topics</h4>
#   <ul class="list-unstyled pb-2 m-0">
#       <li>
#
#
#
#
#
#
# <div class="position-relative pt-1 pb-1 pl-4">
#
#   <a class="topic-toggle"
#     href="#subtopic-container_0"
#     data-toggle="collapse"
#     aria-controls="subtopic-container_0"
#     aria-expanded="true">
#     <i class="material-icons"></i>
#   </a>
#
#   <span class="topic-text-wrapper">
#     <a class="text-black course-info-topic" href="/search?t=Engineering">
#       Engineering
#     </a>
#   </span>
# </div>
#
# <div class="pl-4 subtopic-container collapse show" id="subtopic-container_0">
#
#
#
#   <div class="position-relative pt-1 pb-1  pl-4">
#
#     <a class="topic-toggle"
#       href="#speciality-container_0_0"
#       data-toggle="collapse"
#       aria-controls="speciality-container_0_0"
#       aria-expanded="true">
#       <i class="material-icons"></i>
#     </a>
#
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Computer&#43;Science">
#       Computer Science
#       </a>
#     </span>
#   </div>
#
#   <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Algorithms&#43;and&#43;Data&#43;Structures">
#       Algorithms and Data Structures
#       </a>
#     </span>
#   </div>
#
#   <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Theory&#43;of&#43;Computation">
#       Theory of Computation
#       </a>
#     </span>
#   </div>
#
#
#
# </div>
#
# </li>
#       <li>
#
#
#
#
#
#
# <div class="position-relative pt-1 pb-1 pl-4">
#
#   <a class="topic-toggle"
#     href="#subtopic-container_1"
#     data-toggle="collapse"
#     aria-controls="subtopic-container_1"
#     aria-expanded="false">
#     <i class="material-icons"></i>
#   </a>
#
#   <span class="topic-text-wrapper">
#     <a class="text-black course-info-topic" href="/search?t=Mathematics">
#       Mathematics
#     </a>
#   </span>
# </div>
#
# <div class="pl-4 subtopic-container collapse" id="subtopic-container_1">
#
#
#
#   <div class="position-relative pt-1 pb-1 ">
#
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Computation">
#       Computation
#       </a>
#     </span>
#   </div>
#
#
#
# </div>
#
# </li>
#
#   </ul>
# </div>
#
#
#
#
#
#   <div class="course-home-section w-100 in-panel">
#     <div class="container px-0 mx-0">
#       <h4 class="course-info-title font-weight-bold">Learning Resource Types</h4>
#       <div class="row">
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">theaters</i>
#   <span>Lecture Videos</span>
# </div>
#           </div>
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">assignment_turned_in</i>
#   <span>Problem Sets with Solutions</span>
# </div>
#           </div>
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">grading</i>
#   <span>Exams with Solutions</span>
# </div>
#           </div>
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">notes</i>
#   <span>Lecture Notes</span>
# </div>
#           </div>
#
#       </div>
#     </div>
#   </div>
#
#
# </div>
#
#
# <div
#   id="mobile-header"
#   class="position-relative bg-black medium-and-below-only"
# >
#   <nav class="navbar navbar-expand-lg navbar-dark bg-black">
#     <button
#       class="navbar-toggler"
#       type="button"
#       data-toggle="collapse"
#       data-target="#navbarSupportedContent"
#       aria-controls="navbarSupportedContent"
#       aria-expanded="false"
#       aria-label="Toggle navigation"
#     >
#       <i class="material-icons display-4 text-white align-bottom">menu</i>
#     </button>
#     <div class="mx-auto">
#       <a href="/">
#         <img
#           width="250"
#           src="/images/ocw_logo_white.png"
#           alt="MIT OpenCourseWare"
#         />
#       </a>
#     </div>
#     <div class="collapse navbar-collapse" id="navbarSupportedContent">
#       <ul class="navbar-nav mr-auto pl-2 pt-2">
#         <li class="nav-item">
#
#
#     <a class="nav-link search-icon pr-6" href="/search">
#       <i class="material-icons">search</i>
#     </a>
#
# </li>
#         <li class="nav-item">
#           <a
#             class="nav-link"
#             href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home"
#             >Give Now</a
#           >
#         </li>
#         <li class="nav-item">
#           <a class="nav-link" href="/about">About OCW</a>
#         </li>
#         <li class="nav-item">
#           <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help & Faqs</a>
#         </li>
#         <li class="nav-item">
#           <a class="nav-link" href="/contact">
#             Contact Us
#           </a>
#         </li>
#       </ul>
#     </div>
#   </nav>
# </div>
#
#
# <div id="desktop-header">
#   <div class="contents px-6">
#     <div class="left">
#       <div class="ocw-logo mr-6">
#         <a href="/">
#           <img src="/images/ocw_logo_white.png" alt="MIT OpenCourseWare" />
#         </a>
#       </div>
#     </div>
#     <div class="right">
#
#
#
#     <a class="nav-link search-icon pr-6" href="/search">
#       <i class="material-icons">search</i>
#     </a>
#
#
#       <a
#         class="d-flex give-button-header py-2 px-3"
#         href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home"
#       >
#         <span class="font-weight-bold w-100">Give now</span>
#       </a>
#       <a href="/about">
#         <div class="text-white font-weight-bold w-100 px-3 pl-5 py-2">
#           About OCW
#         </div>
#       </a>
#       <a href="https://mitocw.zendesk.com/hc/en-us" target="_blank">
#         <div class="text-white font-weight-bold w-100 px-3 py-2">
#           help & faqs
#         </div>
#       </a>
#       <a href="/contact">
#         <div class="text-white font-weight-bold w-100 px-3 py-2">
#           contact us
#         </div>
#       </a>
#     </div>
#   </div>
# </div>
#
#
#
#     <div class="course-info-toggle medium-and-below-only bg-light shadow-sm border border-right-0 rounded-left">
#       <div class="btn px-2 m-0 toggle navbar-toggle offcanvas-toggle text-uppercase font-weight-bold"
#         data-toggle="offcanvas" data-target="#course-info-drawer">
#         Course Info
#       </div>
#     </div>
#
#
#
# <div id="course-banner" class="p-0">
#   <div class="max-content-width m-auto px-5 py-6">
#
#
#     <a
#       class="text-uppercase display-4 font-weight-bold m-0 text-white"
#       href="/courses/6-006-introduction-to-algorithms-spring-2020/"
#     >Introduction to Algorithms</a>
#   </div>
# </div>
#
#     <div class="container-fluid">
#       <div class="row outer-wrapper">
#         <div class="col-lg-3 pl-5 pr-0 py-4 large-and-above-only desktop-nav bg-light">
#   <div class="h-100">
#
# <nav id="course-nav" class="course-nav">
#   <ul class="w-100 m-auto list-unstyled">
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/syllabus">
#         Syllabus
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_806697d9-a77b-cfb5-791d-be64ae934dc9">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/calendar">
#         Calendar
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_7d2ea4af-b24a-df20-2423-9a0889bc50ab">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/video_galleries/lecture-videos">
#         Lecture Videos
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_2dd8a6bf-697c-cc23-b282-ae6f9dec5b6f">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/lecture-notes">
#         Lecture Notes
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_51ba9637-0a92-32f2-88ab-0bef851c9ad4">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/quizzes">
#         Quizzes
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_400e6a8d-35c4-e497-f645-fe19629c58f3">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/practice-problems">
#         Practice Problems
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_60da50f1-00f1-a813-476b-6e6a65e98226">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/assignments">
#         Assignments
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_bdb6c046-d849-dd11-ab64-cdea4975d145">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#
#
#
#
#
# <li class="course-nav-list-item">
#   <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
#     <span class="course-nav-text-wrapper">
#       <a class="text-uppercase text-dark nav-link"
#         href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/resource-index">
#         Resource Index
#       </a>
#     </span>
#
#   </div>
#
#   <span class="medium-and-below-only"><hr/></span>
#
#   <div class="collapse"
#     id="nav-container_d8f3bab7-a81a-a2de-20cc-c78674a64694">
#     <ul class="course-nav-child-nav m-auto">
#
#     </ul>
#   </div>
# </li>
#
#
#   </ul>
# </nav>
#
#   </div>
# </div>
#
#         <div class="left-col-bg"></div>
#         <div id="main-content-wrapper" class="col-lg-9 p-0 bg-white">
#           <main>
#             <div class="container-fluid p-0">
#               <div class="row m-0">
#                 <div id="main-content" class="col-12 col-lg-8 col-xl-8 px-3 pl-md-5 pr-md-8 mt-3 mt-lg-5">
#
#                   <button id="desktop-course-info-toggle" class="course-info-toggle large-and-above-only bg-light shadow-sm border border-right-0 rounded-left p-0" data-toggle="collapse">
#                     <span  class="btn px-2 m-0 toggle navbar-toggle offcanvas-toggle text-uppercase font-weight-bold">
#                       Hide Course Info
#                   </span>
#                   </button>
#
#
#
# <div class="rounded mb-2">
#
# <header>
#   <div
#     class="course-section-title-container "
#     id="course-title"
#   >
#
#     <h1 class="text-uppercase font-weight-bold pb-1 mb-3">Lecture Videos</h1>
#   </div>
#   <div class="d-flex">
#
#   </div>
# </header>
#   <div class="mobile-course-nav-toggle medium-and-below-only mb-2">
#   <div
#     id="mobile-course-nav-toggle"
#     class="btn bg-blue white-color d-inline-flex align-items-center rounded-0 navbar-toggle offcanvas-toggle"
#     data-toggle="offcanvas"
#     data-target="#mobile-course-nav"
#   >
#     <i class="material-icons pr-2">arrow_back</i>
#     <span class="text-uppercase font-weight-bold pr-2">browse course material</span>
#     <i class="material-icons pr-2">library_books</i>
#   </div>
# </div>
#   <article class="content pt-3 mt-1 mr-5 mr-md-0">
#     <main id="course-content-section"></main>
#   </article>
# </div>
#
#
# <div class="mb-5">
#
#
#
#
#
#
#
#
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_04_Lecture_1_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-1-algorithms-and-computation/">
#         Lecture 1: Algorithms and Computation
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_10_Lecture_10_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-10-depth-first-search/">
#         Lecture 10: Depth-First Search
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_12_Lecture_11_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-11-weighted-shortest-paths/">
#         Lecture 11: Weighted Shortest Paths
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_19_Lecture_12_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-12-bellman-ford/">
#         Lecture 12: Bellman-Ford
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_07_Lecture_13_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-13-dijkstra/">
#         Lecture 13: Dijkstra
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_09_Lecture_14_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-14-apsp-and-johnson/">
#         Lecture 14: APSP and Johnson
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_14_Lecture_15_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-15-dynamic-programming-part-1-srtbot-fib-dags-bowling/">
#         Lecture 15: Dynamic Programming, Part 1: SRTBOT, Fib, DAGs, Bowling
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_16_Lecture_16_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-16-dynamic-programming-part-2-lcs-lis-coins/">
#         Lecture 16: Dynamic Programming, Part 2: LCS, LIS, Coins
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_23_Lecture_17_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-17-dynamic-programming-part-3-apsp-parens-piano/">
#         Lecture 17: Dynamic Programming, Part 3: APSP, Parens, Piano
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_28_Lecture_18_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-18-dynamic-programming-part-4-rods-subset-sum-pseudopolynomial/">
#         Lecture 18: Dynamic Programming, Part 4: Rods, Subset Sum, Pseudopolynomial
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_30_Lecture_19_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-19-complexity/">
#         Lecture 19: Complexity
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_06_Lecture_2_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-2-data-structures-and-dynamic-arrays/">
#         Lecture 2: Data Structures and Dynamic Arrays
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_05_05_Lecture_20_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-20-course-review/">
#         Lecture 20: Course Review
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_05_12_Lecture_21_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-21-algorithms2014next-steps/">
#         Lecture 21: AlgorithmsâNext Steps
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_11_Lecture_3_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-3-sets-and-sorting/">
#         Lecture 3: Sets and Sorting
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_13_Lecture_4_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-4-hashing/">
#         Lecture 4: Hashing
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_20_Lecture_5_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-5-linear-sorting/">
#         Lecture 5: Linear Sorting
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_25_Lecture_6_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-6-binary-trees-part-1/">
#         Lecture 6: Binary Trees, Part 1
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_27_Lecture_7_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-7-binary-trees-part-2-avl/">
#         Lecture 7: Binary Trees, Part 2: AVL
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_03_Lecture_8_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-8-binary-heaps/">
#         Lecture 8: Binary Heaps
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_05_Lecture_9_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-9-breadth-first-search/">
#         Lecture 9: Breadth-First Search
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_07_Problem_Session_1_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-1/">
#         Problem Session 1
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_14_Problem_Session_2_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-2/">
#         Problem Session 2
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_21_Problem_Session_3_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-3/">
#         Problem Session 3
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_28_Problem_Session_4_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-4/">
#         Problem Session 4
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_13_Problem_Session_5_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-5/">
#         Problem Session 5
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_06_Problem_Session_6_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-6/">
#         Problem Session 6
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_07_Problem_Session_7_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-7/">
#         Problem Session 7
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_17_Problem_Session_8_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-8/">
#         Problem Session 8
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_06_Quiz_1_Review_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-1-review/">
#         Quiz 1 Review
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_13_Quiz_2_Review_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-2-review/">
#         Quiz 2 Review
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#     <div class="container">
#   <div class="row">
#     <div class="d-inline-flex">
#
#
#         <img
#           class="resource-thumbnail"
#           src="/images/mobile_video_thumbnail.png"
#         />
#
#
#
#
#           <span class="pr-2">
#
#               <a href="https://archive.org/download/MIT6.006S20/MIT6_006S20_05_02_Quiz_3_Review_300k.mp4" target="_blank" download>
#                 <img
#                   class="resource-download"
#                   src="/images/download.svg"
#                 />
#               </a>
#
#           </span>
#
#       <div class="pt-2">
#       <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-3-review/">
#         Quiz 3 Review
#       </a>
#       </div>
#     </div>
#   </div>
# </div>
# <hr>
#
#
#
#
# </div>
#
#                 </div>
#
#                 <div id="desktop-course-info" class="col-12 col-lg-4 col-xl-4 px-6 mt-6 large-and-above-only border-left-gray">
#
#
# <div class="table-responsive course-info">
#   <div class="course-info-expander">
#     <h4 class="course-info-title font-weight-bold">Course Info</h4>
#   </div>
#   <div id="course-info" class="position-relative " aria-expanded="false">
#     <table id="course-info-table" class="table table-borderless mb-0" >
#
#       <tr>
#
#         <td class="pl-0">Instructors:</td>
#         <td>
#
#
#
#
#
# <ul class="list-unstyled m-0">
#
#
#
#
#
#   <li>
#
#     <a href="/search?q=Prof.&#43;Erik&#43;Demaine" class="course-info-instructor">
#       Prof. Erik Demaine
#     </a>
#
#   </li>
#
#
#
#
#
#   <li>
#
#     <a href="/search?q=Dr.&#43;Jason&#43;Ku" class="course-info-instructor">
#       Dr. Jason Ku
#     </a>
#
#   </li>
#
#
#
#
#
#   <li>
#
#     <a href="/search?q=Prof.&#43;Justin&#43;Solomon" class="course-info-instructor">
#       Prof. Justin Solomon
#     </a>
#
#   </li>
#
# </ul>
#
#
#         </td>
#       </tr>
#
#       <tr>
#         <td class="pl-0">Course Number:</td>
#         <td>
#
#
#
#
# <ul class="list-unstyled m-0">
#
#
#
#
#
#   <li>
#
#     6.006
#
#   </li>
#
#
#
#
#
#   <li>
#
#
#
#   </li>
#
# </ul>
#
# </td>
#       </tr>
#
#       <tr>
#         <td class="pl-0">Departments:</td>
#         <td>
#
#
#
#
#
#
# <ul class="list-unstyled m-0">
#
#
#
#
#
#   <li>
#
#     <a href="/search?d=Electrical&#43;Engineering&#43;and&#43;Computer&#43;Science" class="course-info-department">
#       Electrical Engineering and Computer Science
#     </a>
#
#   </li>
#
# </ul>
#
#
#         </td>
#       </tr>
#
#
#       <tr>
#         <td class="pl-0 text-nowrap">As Taught In:</td>
#         <td>
#           Spring 2020
#         </td>
#       </tr>
#       <tr>
#         <td class="pl-0">Level:</td>
#         <td>
#
#
#
#               <a href="/search?l=Undergraduate" class="course-info-level">
#                 Undergraduate
#               </a><br />
#
#
#         </td>
#       </tr>
#     </table>
#   </div>
# </div>
# <div class="border-top-gray ">
#
# </div>
#
#
#
#
# <div class="border-bottom-gray my-2">
#   <h4 class="course-info-title font-weight-bold">Topics</h4>
#   <ul class="list-unstyled pb-2 m-0">
#       <li>
#
#
#
#
#
#
# <div class="position-relative pt-1 pb-1 pl-4">
#
#   <a class="topic-toggle"
#     href="#subtopic-container_0"
#     data-toggle="collapse"
#     aria-controls="subtopic-container_0"
#     aria-expanded="true">
#     <i class="material-icons"></i>
#   </a>
#
#   <span class="topic-text-wrapper">
#     <a class="text-black course-info-topic" href="/search?t=Engineering">
#       Engineering
#     </a>
#   </span>
# </div>
#
# <div class="pl-4 subtopic-container collapse show" id="subtopic-container_0">
#
#
#
#   <div class="position-relative pt-1 pb-1  pl-4">
#
#     <a class="topic-toggle"
#       href="#speciality-container_0_0"
#       data-toggle="collapse"
#       aria-controls="speciality-container_0_0"
#       aria-expanded="true">
#       <i class="material-icons"></i>
#     </a>
#
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Computer&#43;Science">
#       Computer Science
#       </a>
#     </span>
#   </div>
#
#   <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Algorithms&#43;and&#43;Data&#43;Structures">
#       Algorithms and Data Structures
#       </a>
#     </span>
#   </div>
#
#   <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Theory&#43;of&#43;Computation">
#       Theory of Computation
#       </a>
#     </span>
#   </div>
#
#
#
# </div>
#
# </li>
#       <li>
#
#
#
#
#
#
# <div class="position-relative pt-1 pb-1 pl-4">
#
#   <a class="topic-toggle"
#     href="#subtopic-container_1"
#     data-toggle="collapse"
#     aria-controls="subtopic-container_1"
#     aria-expanded="false">
#     <i class="material-icons"></i>
#   </a>
#
#   <span class="topic-text-wrapper">
#     <a class="text-black course-info-topic" href="/search?t=Mathematics">
#       Mathematics
#     </a>
#   </span>
# </div>
#
# <div class="pl-4 subtopic-container collapse" id="subtopic-container_1">
#
#
#
#   <div class="position-relative pt-1 pb-1 ">
#
#     <span class="topic-text-wrapper">
#       <a class="text-black course-info-topic" href="/search?t=Computation">
#       Computation
#       </a>
#     </span>
#   </div>
#
#
#
# </div>
#
# </li>
#
#   </ul>
# </div>
#
#
#
#
#
#   <div class="course-home-section w-100 in-panel">
#     <div class="container px-0 mx-0">
#       <h4 class="course-info-title font-weight-bold">Learning Resource Types</h4>
#       <div class="row">
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">theaters</i>
#   <span>Lecture Videos</span>
# </div>
#           </div>
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">assignment_turned_in</i>
#   <span>Problem Sets with Solutions</span>
# </div>
#           </div>
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">grading</i>
#   <span>Exams with Solutions</span>
# </div>
#           </div>
#
#           <div class="col-12">
#             <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
#   <i class="course-feature-icon material-icons h2 pr-2 mb-0">notes</i>
#   <span>Lecture Notes</span>
# </div>
#           </div>
#
#       </div>
#     </div>
#   </div>
#
#
# </div>
#
#
#               </div>
#             </div>
#           </main>
#         </div>
#       </div>
#     </div>
#     <footer id="footer-container">
#   <div class="row pb-4 mx-0 justify-content-between">
#     <div>
#       <a
#         id="open-learning-logo"
#         href="https://openlearning.mit.edu/"
#         target="_blank"
#       >
#         <img src="/images/mit-ol.png" alt="MIT Open Learning" />
#       </a>
#     </div>
#     <div
#       class="d-flex md-and-above-only align-items-center support-link-container"
#     >
#       <a href="https://accessibility.mit.edu">Accessibility</a>
#       <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/"
#         >Creative Commons License</a
#       >
#       <a href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
#     </div>
#   </div>
#   <div class="row pb-4 mx-0 justify-content-between row-gap-20">
#     <div class="about-courseware">
#       <p>
#         MIT OpenCourseWare is an online publication of materials from over 2,500
#         MIT courses, freely sharing knowledge with learners and educators around
#         the world. <a href="/about">Learn more</a>
#       </p>
#     </div>
#     <div
#       class="d-flex sm-and-below-only align-items-start support-link-column flex-column row-gap-20"
#     >
#       <a href="https://accessibility.mit.edu">Accessibility</a>
#       <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/"
#         >Creative Commons License</a
#       >
#       <a href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
#     </div>
#     <div class="row mx-0 align-items-center">
#       <p class="font-weight-bold">
#         PROUD MEMBER OF :
#         <a href="https://www.oeglobal.org/" target="_blank"
#           ><img class="oeg-logo" src="/images/oeg_logo.png" alt="Open Education Global"
#         /></a>
#       </p>
#     </div>
#   </div>
#   <div class="row mx-0 justify-content-between flex-wrap-reverse row-gap-20">
#     <div class="d-flex align-items-end mr-3">
#       <p>
#         Â© 2001â2022 Massachusetts Institute of Technology
#       </p>
#     </div>
#     <div class="horizontal-list">
#       <ul class="p-0">
#         <li>
#           <a
#             class="img-link"
#             href="https://www.facebook.com/MITOCW"
#             target="_blank"
#           >
#             <img
#               class="footer-social-icon"
#               src="/images/Facebook.png"
#               alt="facebook"
#             />
#           </a>
#         </li>
#         <li>
#           <a
#             class="img-link"
#             href="https://www.instagram.com/mitocw"
#             target="_blank"
#           >
#             <img
#               class="footer-social-icon"
#               src="/images/Instagram.png"
#               alt="instagram"
#             />
#           </a>
#         </li>
#         <li>
#           <a class="img-link" href="https://twitter.com/MITOCW" target="_blank">
#             <img class="footer-social-icon" src="/images/Twitter.png" alt="twitter" />
#           </a>
#         </li>
#         <li>
#           <a
#             class="img-link"
#             href="https://www.youtube.com/mitocw"
#             target="_blank"
#           >
#             <img class="footer-social-icon" src="/images/Youtube.png" alt="youtube" />
#           </a>
#         </li>
#         <li>
#           <a
#             class="img-link"
#             href="https://www.linkedin.com/company/mit-opencourseware/"
#             target="_blank"
#           >
#             <img
#               class="footer-social-icon"
#               src="/images/LinkedIn.png"
#               alt="LinkedIn"
#             />
#           </a>
#         </li>
#       </ul>
#     </div>
#   </div>
# </footer>
#
#   </div>
#   <script>
#     window.MathJax = {
#       TeX: {
#         equationNumbers: {
#           autoNumber: "AMS"
#         }
#       },
#       displayAlign: "left",
#       displayIndent: "2em",
#       menuSettings: {
#         zoom: "Double-Click",
#         mpContext: true,
#         mpMouse: true
#       },
#       errorSettings: {
#         message: ["[Math Error]"]
#       }
#     }
#
#   </script>
#
#
# <script>
# function courseNav(){document.querySelectorAll(".course-nav, .transcript-header").forEach(e=>{e.querySelectorAll(".nav-link").forEach(e=>{const t=e.getAttribute("href")?e.getAttribute("href"):"";t.replace(/\/$/,"")===window.location.pathname.replace(/\/$/,"")&&e.classList.add("active")});const t=e.querySelector("a.nav-link.active");e.querySelectorAll(".course-nav-list-item").forEach(n=>{const e=n.querySelector(".collapse");e&&e.contains(t)&&(e.classList.add("show"),n.querySelector(".course-nav-section-toggle, video-tab-section-toggle").setAttribute("aria-expanded","true"))})})}courseNav()
# </script>
#
#
#
# <script>
# function initResponsiveTables(){const e=document.getElementById("main-content").getElementsByTagName("table");for(const t of e){const n=t.getElementsByTagName("th"),s=t.getElementsByTagName("tbody")[0],o=s.getElementsByTagName("tr");for(const t of o){const e=t.getElementsByTagName("td");for(let t=0;t<e.length;t++)n.length>=t+1&&e[t].setAttribute("data-title",n[t].innerText.trim().concat(": "))}const i=t.clientWidth,a=document.getElementById("main-content").clientWidth;i>a&&t.classList.add("mobile-table")}}initResponsiveTables()
# </script>
# <script src="/static/js/main.80259.js"></script>
#   <script src="/static/js/course.80259.js"></script>
#   <script src="/static/mathjax/tex-svg.js" defer></script>
#
#
#   <script async src="https://w.appzi.io/w.js?token=Tgs1d"></script>
#
#
# </body>
#
# </html>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="/static/css/course.80259.css" rel="stylesheet"/>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NMQZ25T');</script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
# <meta content="MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity" name="description"/>
# <meta content="opencourseware,MIT OCW,courseware,MIT opencourseware,Free Courses,class notes,class syllabus,class materials,tutorials,online courses,MIT courses" name="keywords"/>
# <link href="https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-videos/" rel="canonical">
# <script type="application/ld+json">
#       {
#         "@context": "http://schema.org/",
#         "@type" : "WebPage",
#         "name": "MIT OpenCourseWare",
#         "description": "MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity",
#         "license": "http://creativecommons.org/licenses/by-nc-sa/4.0/",
#         "publisher": {
#           "@type": "CollegeOrUniversity",
#           "name": "MIT OpenCourseWare"
#         }
#       }
#   </script>
# <title>Lecture Videos | Introduction to Algorithms | Electrical Engineering and Computer Science | MIT OpenCourseWare</title>
# <link href="/static/css/main.80259.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,500&amp;display=swap" rel="stylesheet"/>
# <style>
#   @font-face {
#     font-family: 'Material Icons';
#     font-style: normal;
#     font-weight: 400;
#     src: local('Material Icons'),
#       local('MaterialIcons-Regular'),
#       url(/static/fonts/MaterialIcons-Regular.woff2) format('woff2'),
#       url(/static/fonts/MaterialIcons-Regular.woff) format('woff'),
#       url(/static/fonts/MaterialIcons-Regular.ttf) format('truetype');
#   }
#   @font-face {
#     font-family: 'Material Icons Round';
#     font-style: normal;
#     font-weight: 400;
#     src: local("MaterialIcons-Round"),
#     url(/static/fonts/MaterialIconsRound-Regular.woff2) format('woff2');
#   }
#   @font-face {
#     font-family: 'Cardo Bold';
#     font-style: normal;
#     font-weight: bold;
#     src: local('Cardo'),
#       local('Cardo-Bold'),
#       url(/static/fonts/Cardo-Bold.ttf) format('truetype');
#   }
#   @font-face {
#     font-family: 'Cardo Italic';
#     font-style: italic;
#     font-weight: 400;
#     src: local('Cardo'),
#       local('Cardo-Italic'),
#       url(/static/fonts/Cardo-Italic.ttf) format('truetype');
#   }
#   @font-face {
#     font-family: 'Helvetica Light';
#     font-style: normal`;
#     font-weight: 400;
#     src: local('Helvetica Light'),
#       local('Helvetica-Light'),
#       url(/static/fonts/Helvetica-Light.ttf) format('truetype');
#   }
#   </style>
# </link></head>
# <body class="course-home-page">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NMQZ25T" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="overflow-auto">
# <div class="navbar-offcanvas medium-and-below-only nav-drawer" id="mobile-course-nav">
# <h5 class="text-uppercase mb-4 mt-4">Browse Course Material</h5>
# <nav class="course-nav" id="course-nav">
# <ul class="w-100 m-auto list-unstyled">
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/syllabus">
#         Syllabus
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_806697d9-a77b-cfb5-791d-be64ae934dc9">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/calendar">
#         Calendar
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_7d2ea4af-b24a-df20-2423-9a0889bc50ab">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/video_galleries/lecture-videos">
#         Lecture Videos
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_2dd8a6bf-697c-cc23-b282-ae6f9dec5b6f">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/lecture-notes">
#         Lecture Notes
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_51ba9637-0a92-32f2-88ab-0bef851c9ad4">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/quizzes">
#         Quizzes
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_400e6a8d-35c4-e497-f645-fe19629c58f3">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/practice-problems">
#         Practice Problems
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_60da50f1-00f1-a813-476b-6e6a65e98226">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/assignments">
#         Assignments
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_bdb6c046-d849-dd11-ab64-cdea4975d145">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/resource-index">
#         Resource Index
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_d8f3bab7-a81a-a2de-20cc-c78674a64694">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <div class="bg-faded pt-3 bg-light navbar-offcanvas navbar-offcanvas-right medium-and-below-only nav-drawer" id="course-info-drawer">
# <div class="table-responsive course-info">
# <div class="course-info-expander">
# <h4 class="course-info-title font-weight-bold">Course Info</h4>
# </div>
# <div aria-expanded="false" class="position-relative" id="course-info">
# <table class="table table-borderless mb-0" id="course-info-table">
# <tr>
# <td class="pl-0">Instructors:</td>
# <td>
# <ul class="list-unstyled m-0">
# <li>
# <a class="course-info-instructor" href="/search?q=Prof.+Erik+Demaine">
#       Prof. Erik Demaine
#     </a>
# </li>
# <li>
# <a class="course-info-instructor" href="/search?q=Dr.+Jason+Ku">
#       Dr. Jason Ku
#     </a>
# </li>
# <li>
# <a class="course-info-instructor" href="/search?q=Prof.+Justin+Solomon">
#       Prof. Justin Solomon
#     </a>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <td class="pl-0">Course Number:</td>
# <td>
# <ul class="list-unstyled m-0">
# <li>
#
#     6.006
#
#   </li>
# <li>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <td class="pl-0">Departments:</td>
# <td>
# <ul class="list-unstyled m-0">
# <li>
# <a class="course-info-department" href="/search?d=Electrical+Engineering+and+Computer+Science">
#       Electrical Engineering and Computer Science
#     </a>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <td class="pl-0 text-nowrap">As Taught In:</td>
# <td>
#           Spring 2020
#         </td>
# </tr>
# <tr>
# <td class="pl-0">Level:</td>
# <td>
# <a class="course-info-level" href="/search?l=Undergraduate">
#                 Undergraduate
#               </a><br/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div class="border-top-gray">
# </div>
# <div class="border-bottom-gray my-2">
# <h4 class="course-info-title font-weight-bold">Topics</h4>
# <ul class="list-unstyled pb-2 m-0">
# <li>
# <div class="position-relative pt-1 pb-1 pl-4">
# <a aria-controls="subtopic-container_0" aria-expanded="true" class="topic-toggle" data-toggle="collapse" href="#subtopic-container_0">
# <i class="material-icons"></i>
# </a>
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Engineering">
#       Engineering
#     </a>
# </span>
# </div>
# <div class="pl-4 subtopic-container collapse show" id="subtopic-container_0">
# <div class="position-relative pt-1 pb-1 pl-4">
# <a aria-controls="speciality-container_0_0" aria-expanded="true" class="topic-toggle" data-toggle="collapse" href="#speciality-container_0_0">
# <i class="material-icons"></i>
# </a>
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Computer+Science">
#       Computer Science
#       </a>
# </span>
# </div>
# <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Algorithms+and+Data+Structures">
#       Algorithms and Data Structures
#       </a>
# </span>
# </div>
# <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Theory+of+Computation">
#       Theory of Computation
#       </a>
# </span>
# </div>
# </div>
# </li>
# <li>
# <div class="position-relative pt-1 pb-1 pl-4">
# <a aria-controls="subtopic-container_1" aria-expanded="false" class="topic-toggle" data-toggle="collapse" href="#subtopic-container_1">
# <i class="material-icons"></i>
# </a>
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Mathematics">
#       Mathematics
#     </a>
# </span>
# </div>
# <div class="pl-4 subtopic-container collapse" id="subtopic-container_1">
# <div class="position-relative pt-1 pb-1">
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Computation">
#       Computation
#       </a>
# </span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="course-home-section w-100 in-panel">
# <div class="container px-0 mx-0">
# <h4 class="course-info-title font-weight-bold">Learning Resource Types</h4>
# <div class="row">
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">theaters</i>
# <span>Lecture Videos</span>
# </div>
# </div>
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">assignment_turned_in</i>
# <span>Problem Sets with Solutions</span>
# </div>
# </div>
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">grading</i>
# <span>Exams with Solutions</span>
# </div>
# </div>
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">notes</i>
# <span>Lecture Notes</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="position-relative bg-black medium-and-below-only" id="mobile-header">
# <nav class="navbar navbar-expand-lg navbar-dark bg-black">
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <i class="material-icons display-4 text-white align-bottom">menu</i>
# </button>
# <div class="mx-auto">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/images/ocw_logo_white.png" width="250"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto pl-2 pt-2">
# <li class="nav-item">
# <a class="nav-link search-icon pr-6" href="/search">
# <i class="material-icons">search</i>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/about">About OCW</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/contact">
#             Contact Us
#           </a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# <div id="desktop-header">
# <div class="contents px-6">
# <div class="left">
# <div class="ocw-logo mr-6">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/images/ocw_logo_white.png"/>
# </a>
# </div>
# </div>
# <div class="right">
# <a class="nav-link search-icon pr-6" href="/search">
# <i class="material-icons">search</i>
# </a>
# <a class="d-flex give-button-header py-2 px-3" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="font-weight-bold w-100">Give now</span>
# </a>
# <a href="/about">
# <div class="text-white font-weight-bold w-100 px-3 pl-5 py-2">
#           About OCW
#         </div>
# </a>
# <a href="https://mitocw.zendesk.com/hc/en-us" target="_blank">
# <div class="text-white font-weight-bold w-100 px-3 py-2">
#           help &amp; faqs
#         </div>
# </a>
# <a href="/contact">
# <div class="text-white font-weight-bold w-100 px-3 py-2">
#           contact us
#         </div>
# </a>
# </div>
# </div>
# </div>
# <div class="course-info-toggle medium-and-below-only bg-light shadow-sm border border-right-0 rounded-left">
# <div class="btn px-2 m-0 toggle navbar-toggle offcanvas-toggle text-uppercase font-weight-bold" data-target="#course-info-drawer" data-toggle="offcanvas">
#         Course Info
#       </div>
# </div>
# <div class="p-0" id="course-banner">
# <div class="max-content-width m-auto px-5 py-6">
# <a class="text-uppercase display-4 font-weight-bold m-0 text-white" href="/courses/6-006-introduction-to-algorithms-spring-2020/">Introduction to Algorithms</a>
# </div>
# </div>
# <div class="container-fluid">
# <div class="row outer-wrapper">
# <div class="col-lg-3 pl-5 pr-0 py-4 large-and-above-only desktop-nav bg-light">
# <div class="h-100">
# <nav class="course-nav" id="course-nav">
# <ul class="w-100 m-auto list-unstyled">
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/syllabus">
#         Syllabus
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_806697d9-a77b-cfb5-791d-be64ae934dc9">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/calendar">
#         Calendar
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_7d2ea4af-b24a-df20-2423-9a0889bc50ab">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/video_galleries/lecture-videos">
#         Lecture Videos
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_2dd8a6bf-697c-cc23-b282-ae6f9dec5b6f">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/lecture-notes">
#         Lecture Notes
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_51ba9637-0a92-32f2-88ab-0bef851c9ad4">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/quizzes">
#         Quizzes
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_400e6a8d-35c4-e497-f645-fe19629c58f3">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/practice-problems">
#         Practice Problems
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_60da50f1-00f1-a813-476b-6e6a65e98226">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/assignments">
#         Assignments
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_bdb6c046-d849-dd11-ab64-cdea4975d145">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# <li class="course-nav-list-item">
# <div class="course-nav-parent d-flex flex-direction-row align-items-center justify-content-between pt-2 pb-2">
# <span class="course-nav-text-wrapper">
# <a class="text-uppercase text-dark nav-link" href="/courses/6-006-introduction-to-algorithms-spring-2020/pages/resource-index">
#         Resource Index
#       </a>
# </span>
# </div>
# <span class="medium-and-below-only"><hr/></span>
# <div class="collapse" id="nav-container_d8f3bab7-a81a-a2de-20cc-c78674a64694">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="left-col-bg"></div>
# <div class="col-lg-9 p-0 bg-white" id="main-content-wrapper">
# <main>
# <div class="container-fluid p-0">
# <div class="row m-0">
# <div class="col-12 col-lg-8 col-xl-8 px-3 pl-md-5 pr-md-8 mt-3 mt-lg-5" id="main-content">
# <button class="course-info-toggle large-and-above-only bg-light shadow-sm border border-right-0 rounded-left p-0" data-toggle="collapse" id="desktop-course-info-toggle">
# <span class="btn px-2 m-0 toggle navbar-toggle offcanvas-toggle text-uppercase font-weight-bold">
#                       Hide Course Info
#                   </span>
# </button>
# <div class="rounded mb-2">
# <header>
# <div class="course-section-title-container" id="course-title">
# <h1 class="text-uppercase font-weight-bold pb-1 mb-3">Lecture Videos</h1>
# </div>
# <div class="d-flex">
# </div>
# </header>
# <div class="mobile-course-nav-toggle medium-and-below-only mb-2">
# <div class="btn bg-blue white-color d-inline-flex align-items-center rounded-0 navbar-toggle offcanvas-toggle" data-target="#mobile-course-nav" data-toggle="offcanvas" id="mobile-course-nav-toggle">
# <i class="material-icons pr-2">arrow_back</i>
# <span class="text-uppercase font-weight-bold pr-2">browse course material</span>
# <i class="material-icons pr-2">library_books</i>
# </div>
# </div>
# <article class="content pt-3 mt-1 mr-5 mr-md-0">
# <main id="course-content-section"></main>
# </article>
# </div>
# <div class="mb-5">
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_04_Lecture_1_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-1-algorithms-and-computation/">
#         Lecture 1: Algorithms and Computation
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_10_Lecture_10_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-10-depth-first-search/">
#         Lecture 10: Depth-First Search
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_12_Lecture_11_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-11-weighted-shortest-paths/">
#         Lecture 11: Weighted Shortest Paths
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_19_Lecture_12_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-12-bellman-ford/">
#         Lecture 12: Bellman-Ford
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_07_Lecture_13_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-13-dijkstra/">
#         Lecture 13: Dijkstra
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_09_Lecture_14_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-14-apsp-and-johnson/">
#         Lecture 14: APSP and Johnson
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_14_Lecture_15_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-15-dynamic-programming-part-1-srtbot-fib-dags-bowling/">
#         Lecture 15: Dynamic Programming, Part 1: SRTBOT, Fib, DAGs, Bowling
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_16_Lecture_16_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-16-dynamic-programming-part-2-lcs-lis-coins/">
#         Lecture 16: Dynamic Programming, Part 2: LCS, LIS, Coins
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_23_Lecture_17_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-17-dynamic-programming-part-3-apsp-parens-piano/">
#         Lecture 17: Dynamic Programming, Part 3: APSP, Parens, Piano
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_28_Lecture_18_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-18-dynamic-programming-part-4-rods-subset-sum-pseudopolynomial/">
#         Lecture 18: Dynamic Programming, Part 4: Rods, Subset Sum, Pseudopolynomial
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_30_Lecture_19_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-19-complexity/">
#         Lecture 19: Complexity
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_06_Lecture_2_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-2-data-structures-and-dynamic-arrays/">
#         Lecture 2: Data Structures and Dynamic Arrays
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_05_05_Lecture_20_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-20-course-review/">
#         Lecture 20: Course Review
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_05_12_Lecture_21_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-21-algorithms2014next-steps/">
#         Lecture 21: AlgorithmsâNext Steps
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_11_Lecture_3_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-3-sets-and-sorting/">
#         Lecture 3: Sets and Sorting
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_13_Lecture_4_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-4-hashing/">
#         Lecture 4: Hashing
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_20_Lecture_5_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-5-linear-sorting/">
#         Lecture 5: Linear Sorting
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_25_Lecture_6_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-6-binary-trees-part-1/">
#         Lecture 6: Binary Trees, Part 1
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_27_Lecture_7_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-7-binary-trees-part-2-avl/">
#         Lecture 7: Binary Trees, Part 2: AVL
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_03_Lecture_8_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-8-binary-heaps/">
#         Lecture 8: Binary Heaps
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_05_Lecture_9_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-9-breadth-first-search/">
#         Lecture 9: Breadth-First Search
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_07_Problem_Session_1_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-1/">
#         Problem Session 1
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_14_Problem_Session_2_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-2/">
#         Problem Session 2
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_21_Problem_Session_3_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-3/">
#         Problem Session 3
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_02_28_Problem_Session_4_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-4/">
#         Problem Session 4
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_13_Problem_Session_5_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-5/">
#         Problem Session 5
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_06_Problem_Session_6_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-6/">
#         Problem Session 6
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_07_Problem_Session_7_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-7/">
#         Problem Session 7
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_17_Problem_Session_8_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-8/">
#         Problem Session 8
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_03_06_Quiz_1_Review_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-1-review/">
#         Quiz 1 Review
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_04_13_Quiz_2_Review_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-2-review/">
#         Quiz 2 Review
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="row">
# <div class="d-inline-flex">
# <img class="resource-thumbnail" src="/images/mobile_video_thumbnail.png"/>
# <span class="pr-2">
# <a download="" href="https://archive.org/download/MIT6.006S20/MIT6_006S20_05_02_Quiz_3_Review_300k.mp4" target="_blank">
# <img class="resource-download" src="/images/download.svg"/>
# </a>
# </span>
# <div class="pt-2">
# <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-3-review/">
#         Quiz 3 Review
#       </a>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# </div>
# </div>
# <div class="col-12 col-lg-4 col-xl-4 px-6 mt-6 large-and-above-only border-left-gray" id="desktop-course-info">
# <div class="table-responsive course-info">
# <div class="course-info-expander">
# <h4 class="course-info-title font-weight-bold">Course Info</h4>
# </div>
# <div aria-expanded="false" class="position-relative" id="course-info">
# <table class="table table-borderless mb-0" id="course-info-table">
# <tr>
# <td class="pl-0">Instructors:</td>
# <td>
# <ul class="list-unstyled m-0">
# <li>
# <a class="course-info-instructor" href="/search?q=Prof.+Erik+Demaine">
#       Prof. Erik Demaine
#     </a>
# </li>
# <li>
# <a class="course-info-instructor" href="/search?q=Dr.+Jason+Ku">
#       Dr. Jason Ku
#     </a>
# </li>
# <li>
# <a class="course-info-instructor" href="/search?q=Prof.+Justin+Solomon">
#       Prof. Justin Solomon
#     </a>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <td class="pl-0">Course Number:</td>
# <td>
# <ul class="list-unstyled m-0">
# <li>
#
#     6.006
#
#   </li>
# <li>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <td class="pl-0">Departments:</td>
# <td>
# <ul class="list-unstyled m-0">
# <li>
# <a class="course-info-department" href="/search?d=Electrical+Engineering+and+Computer+Science">
#       Electrical Engineering and Computer Science
#     </a>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <td class="pl-0 text-nowrap">As Taught In:</td>
# <td>
#           Spring 2020
#         </td>
# </tr>
# <tr>
# <td class="pl-0">Level:</td>
# <td>
# <a class="course-info-level" href="/search?l=Undergraduate">
#                 Undergraduate
#               </a><br/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div class="border-top-gray">
# </div>
# <div class="border-bottom-gray my-2">
# <h4 class="course-info-title font-weight-bold">Topics</h4>
# <ul class="list-unstyled pb-2 m-0">
# <li>
# <div class="position-relative pt-1 pb-1 pl-4">
# <a aria-controls="subtopic-container_0" aria-expanded="true" class="topic-toggle" data-toggle="collapse" href="#subtopic-container_0">
# <i class="material-icons"></i>
# </a>
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Engineering">
#       Engineering
#     </a>
# </span>
# </div>
# <div class="pl-4 subtopic-container collapse show" id="subtopic-container_0">
# <div class="position-relative pt-1 pb-1 pl-4">
# <a aria-controls="speciality-container_0_0" aria-expanded="true" class="topic-toggle" data-toggle="collapse" href="#speciality-container_0_0">
# <i class="material-icons"></i>
# </a>
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Computer+Science">
#       Computer Science
#       </a>
# </span>
# </div>
# <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Algorithms+and+Data+Structures">
#       Algorithms and Data Structures
#       </a>
# </span>
# </div>
# <div class="pt-1 pb-1 pl-5 collapse show" id="speciality-container_0_0">
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Theory+of+Computation">
#       Theory of Computation
#       </a>
# </span>
# </div>
# </div>
# </li>
# <li>
# <div class="position-relative pt-1 pb-1 pl-4">
# <a aria-controls="subtopic-container_1" aria-expanded="false" class="topic-toggle" data-toggle="collapse" href="#subtopic-container_1">
# <i class="material-icons"></i>
# </a>
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Mathematics">
#       Mathematics
#     </a>
# </span>
# </div>
# <div class="pl-4 subtopic-container collapse" id="subtopic-container_1">
# <div class="position-relative pt-1 pb-1">
# <span class="topic-text-wrapper">
# <a class="text-black course-info-topic" href="/search?t=Computation">
#       Computation
#       </a>
# </span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="course-home-section w-100 in-panel">
# <div class="container px-0 mx-0">
# <h4 class="course-info-title font-weight-bold">Learning Resource Types</h4>
# <div class="row">
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">theaters</i>
# <span>Lecture Videos</span>
# </div>
# </div>
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">assignment_turned_in</i>
# <span>Problem Sets with Solutions</span>
# </div>
# </div>
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">grading</i>
# <span>Exams with Solutions</span>
# </div>
# </div>
# <div class="col-12">
# <div class="d-inline-flex pr-5 pb-2 font-weight-bold">
# <i class="course-feature-icon material-icons h2 pr-2 mb-0">notes</i>
# <span>Lecture Notes</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# </div>
# </div>
# <footer id="footer-container">
# <div class="row pb-4 mx-0 justify-content-between">
# <div>
# <a href="https://openlearning.mit.edu/" id="open-learning-logo" target="_blank">
# <img alt="MIT Open Learning" src="/images/mit-ol.png"/>
# </a>
# </div>
# <div class="d-flex md-and-above-only align-items-center support-link-container">
# <a href="https://accessibility.mit.edu">Accessibility</a>
# <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons License</a>
# <a href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# </div>
# </div>
# <div class="row pb-4 mx-0 justify-content-between row-gap-20">
# <div class="about-courseware">
# <p>
#         MIT OpenCourseWare is an online publication of materials from over 2,500
#         MIT courses, freely sharing knowledge with learners and educators around
#         the world. <a href="/about">Learn more</a>
# </p>
# </div>
# <div class="d-flex sm-and-below-only align-items-start support-link-column flex-column row-gap-20">
# <a href="https://accessibility.mit.edu">Accessibility</a>
# <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons License</a>
# <a href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# </div>
# <div class="row mx-0 align-items-center">
# <p class="font-weight-bold">
#         PROUD MEMBER OF :
#         <a href="https://www.oeglobal.org/" target="_blank"><img alt="Open Education Global" class="oeg-logo" src="/images/oeg_logo.png"/></a>
# </p>
# </div>
# </div>
# <div class="row mx-0 justify-content-between flex-wrap-reverse row-gap-20">
# <div class="d-flex align-items-end mr-3">
# <p>
#         Â© 2001â2022 Massachusetts Institute of Technology
#       </p>
# </div>
# <div class="horizontal-list">
# <ul class="p-0">
# <li>
# <a class="img-link" href="https://www.facebook.com/MITOCW" target="_blank">
# <img alt="facebook" class="footer-social-icon" src="/images/Facebook.png"/>
# </a>
# </li>
# <li>
# <a class="img-link" href="https://www.instagram.com/mitocw" target="_blank">
# <img alt="instagram" class="footer-social-icon" src="/images/Instagram.png"/>
# </a>
# </li>
# <li>
# <a class="img-link" href="https://twitter.com/MITOCW" target="_blank">
# <img alt="twitter" class="footer-social-icon" src="/images/Twitter.png"/>
# </a>
# </li>
# <li>
# <a class="img-link" href="https://www.youtube.com/mitocw" target="_blank">
# <img alt="youtube" class="footer-social-icon" src="/images/Youtube.png"/>
# </a>
# </li>
# <li>
# <a class="img-link" href="https://www.linkedin.com/company/mit-opencourseware/" target="_blank">
# <img alt="LinkedIn" class="footer-social-icon" src="/images/LinkedIn.png"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </footer>
# </div>
# <script>
#     window.MathJax = {
#       TeX: {
#         equationNumbers: {
#           autoNumber: "AMS"
#         }
#       },
#       displayAlign: "left",
#       displayIndent: "2em",
#       menuSettings: {
#         zoom: "Double-Click",
#         mpContext: true,
#         mpMouse: true
#       },
#       errorSettings: {
#         message: ["[Math Error]"]
#       }
#     }
#
#   </script>
# <script>
# function courseNav(){document.querySelectorAll(".course-nav, .transcript-header").forEach(e=>{e.querySelectorAll(".nav-link").forEach(e=>{const t=e.getAttribute("href")?e.getAttribute("href"):"";t.replace(/\/$/,"")===window.location.pathname.replace(/\/$/,"")&&e.classList.add("active")});const t=e.querySelector("a.nav-link.active");e.querySelectorAll(".course-nav-list-item").forEach(n=>{const e=n.querySelector(".collapse");e&&e.contains(t)&&(e.classList.add("show"),n.querySelector(".course-nav-section-toggle, video-tab-section-toggle").setAttribute("aria-expanded","true"))})})}courseNav()
# </script>
# <script>
# function initResponsiveTables(){const e=document.getElementById("main-content").getElementsByTagName("table");for(const t of e){const n=t.getElementsByTagName("th"),s=t.getElementsByTagName("tbody")[0],o=s.getElementsByTagName("tr");for(const t of o){const e=t.getElementsByTagName("td");for(let t=0;t<e.length;t++)n.length>=t+1&&e[t].setAttribute("data-title",n[t].innerText.trim().concat(": "))}const i=t.clientWidth,a=document.getElementById("main-content").clientWidth;i>a&&t.classList.add("mobile-table")}}initResponsiveTables()
# </script>
# <script src="/static/js/main.80259.js"></script>
# <script src="/static/js/course.80259.js"></script>
# <script defer="" src="/static/mathjax/tex-svg.js"></script>
# <script async="" src="https://w.appzi.io/w.js?token=Tgs1d"></script>
# </body>
# </html>

# %%
soup.find('div',attrs= {'id' : "course-banner" })
# Out:
# <div class="p-0" id="course-banner">
# <div class="max-content-width m-auto px-5 py-6">
# <a class="text-uppercase display-4 font-weight-bold m-0 text-white" href="/courses/6-006-introduction-to-algorithms-spring-2020/">Introduction to Algorithms</a>
# </div>
# </div>

# %%
soup.find('div',attrs= {'id' : "course-banner" }).find('a')
# Out:
# <a class="text-uppercase display-4 font-weight-bold m-0 text-white" href="/courses/6-006-introduction-to-algorithms-spring-2020/">Introduction to Algorithms</a>

# %%
course_name = soup.find('div',attrs= {'id' : "course-banner" }).find('a').get_text().strip()
course_name
# Out:
# 'Introduction to Algorithms'

# %%
soup.find('title').get_text()
# Out:
# 'Lecture Videos | Introduction to Algorithms | Electrical Engineering and Computer Science | MIT OpenCourseWare'

# %%
soup.find('title').get_text().split('|')
# Out:
# ['Lecture Videos ',
#  ' Introduction to Algorithms ',
#  ' Electrical Engineering and Computer Science ',
#  ' MIT OpenCourseWare']

# %%
course_name = soup.find('title').get_text().split('|')[1].strip()
course_name
# Out:
# 'Introduction to Algorithms'

# %%
file_name = course_name +'(try).csv'
file_name
# Out:
# 'Introduction to Algorithms(try).csv'

# %%
all_lectures_links = soup.find_all('a', attrs= {'class' :'resource-list-title'})
all_lectures_links
# Out:
# [<a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-1-algorithms-and-computation/">
#          Lecture 1: Algorithms and Computation
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-10-depth-first-search/">
#          Lecture 10: Depth-First Search
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-11-weighted-shortest-paths/">
#          Lecture 11: Weighted Shortest Paths
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-12-bellman-ford/">
#          Lecture 12: Bellman-Ford
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-13-dijkstra/">
#          Lecture 13: Dijkstra
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-14-apsp-and-johnson/">
#          Lecture 14: APSP and Johnson
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-15-dynamic-programming-part-1-srtbot-fib-dags-bowling/">
#          Lecture 15: Dynamic Programming, Part 1: SRTBOT, Fib, DAGs, Bowling
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-16-dynamic-programming-part-2-lcs-lis-coins/">
#          Lecture 16: Dynamic Programming, Part 2: LCS, LIS, Coins
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-17-dynamic-programming-part-3-apsp-parens-piano/">
#          Lecture 17: Dynamic Programming, Part 3: APSP, Parens, Piano
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-18-dynamic-programming-part-4-rods-subset-sum-pseudopolynomial/">
#          Lecture 18: Dynamic Programming, Part 4: Rods, Subset Sum, Pseudopolynomial
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-19-complexity/">
#          Lecture 19: Complexity
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-2-data-structures-and-dynamic-arrays/">
#          Lecture 2: Data Structures and Dynamic Arrays
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-20-course-review/">
#          Lecture 20: Course Review
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-21-algorithms2014next-steps/">
#          Lecture 21: AlgorithmsâNext Steps
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-3-sets-and-sorting/">
#          Lecture 3: Sets and Sorting
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-4-hashing/">
#          Lecture 4: Hashing
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-5-linear-sorting/">
#          Lecture 5: Linear Sorting
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-6-binary-trees-part-1/">
#          Lecture 6: Binary Trees, Part 1
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-7-binary-trees-part-2-avl/">
#          Lecture 7: Binary Trees, Part 2: AVL
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-8-binary-heaps/">
#          Lecture 8: Binary Heaps
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-9-breadth-first-search/">
#          Lecture 9: Breadth-First Search
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-1/">
#          Problem Session 1
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-2/">
#          Problem Session 2
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-3/">
#          Problem Session 3
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-4/">
#          Problem Session 4
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-5/">
#          Problem Session 5
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-6/">
#          Problem Session 6
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-7/">
#          Problem Session 7
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-8/">
#          Problem Session 8
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-1-review/">
#          Quiz 1 Review
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-2-review/">
#          Quiz 2 Review
#        </a>,
#  <a class="resource-list-title" href="/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-3-review/">
#          Quiz 3 Review
#        </a>]

# %%
all_lectures_links[1].get('href')
# Out:
# '/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-10-depth-first-search/'

# %%
print('https://ocw.mit.edu'+all_lectures_links[1].get('href'))
# Out:
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-10-depth-first-search/

# %%
for i in range(len(all_lectures_links)) : 
    print(f"https://ocw.mit.edu{all_lectures_links[i].get('href')}")
    print('--'*60)
# Out:
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-1-algorithms-and-computation/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-10-depth-first-search/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-11-weighted-shortest-paths/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-12-bellman-ford/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-13-dijkstra/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-14-apsp-and-johnson/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-15-dynamic-programming-part-1-srtbot-fib-dags-bowling/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-16-dynamic-programming-part-2-lcs-lis-coins/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-17-dynamic-programming-part-3-apsp-parens-piano/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-18-dynamic-programming-part-4-rods-subset-sum-pseudopolynomial/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-19-complexity/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-2-data-structures-and-dynamic-arrays/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-20-course-review/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-21-algorithms2014next-steps/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-3-sets-and-sorting/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-4-hashing/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-5-linear-sorting/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-6-binary-trees-part-1/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-7-binary-trees-part-2-avl/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-8-binary-heaps/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/lecture-9-breadth-first-search/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-1/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-2/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-3/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-4/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-5/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-6/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-7/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/problem-session-8/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-1-review/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-2-review/
# ------------------------------------------------------------------------------------------------------------------------
# https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/resources/quiz-3-review/
# ------------------------------------------------------------------------------------------------------------------------

# %%
all_lectures_links[1].get_text().strip()
# Out:
# 'Lecture 10: Depth-First Search'

# %%
for lecture in all_lectures_links : 
    print(f'{lecture.get_text().strip()}')
    print('--'*40)
# Out:
# Lecture 1: Algorithms and Computation
# --------------------------------------------------------------------------------
# Lecture 10: Depth-First Search
# --------------------------------------------------------------------------------
# Lecture 11: Weighted Shortest Paths
# --------------------------------------------------------------------------------
# Lecture 12: Bellman-Ford
# --------------------------------------------------------------------------------
# Lecture 13: Dijkstra
# --------------------------------------------------------------------------------
# Lecture 14: APSP and Johnson
# --------------------------------------------------------------------------------
# Lecture 15: Dynamic Programming, Part 1: SRTBOT, Fib, DAGs, Bowling
# --------------------------------------------------------------------------------
# Lecture 16: Dynamic Programming, Part 2: LCS, LIS, Coins
# --------------------------------------------------------------------------------
# Lecture 17: Dynamic Programming, Part 3: APSP, Parens, Piano
# --------------------------------------------------------------------------------
# Lecture 18: Dynamic Programming, Part 4: Rods, Subset Sum, Pseudopolynomial
# --------------------------------------------------------------------------------
# Lecture 19: Complexity
# --------------------------------------------------------------------------------
# Lecture 2: Data Structures and Dynamic Arrays
# --------------------------------------------------------------------------------
# Lecture 20: Course Review
# --------------------------------------------------------------------------------
# Lecture 21: AlgorithmsâNext Steps
# --------------------------------------------------------------------------------
# Lecture 3: Sets and Sorting
# --------------------------------------------------------------------------------
# Lecture 4: Hashing
# --------------------------------------------------------------------------------
# Lecture 5: Linear Sorting
# --------------------------------------------------------------------------------
# Lecture 6: Binary Trees, Part 1
# --------------------------------------------------------------------------------
# Lecture 7: Binary Trees, Part 2: AVL
# --------------------------------------------------------------------------------
# Lecture 8: Binary Heaps
# --------------------------------------------------------------------------------
# Lecture 9: Breadth-First Search
# --------------------------------------------------------------------------------
# Problem Session 1
# --------------------------------------------------------------------------------
# Problem Session 2
# --------------------------------------------------------------------------------
# Problem Session 3
# --------------------------------------------------------------------------------
# Problem Session 4
# --------------------------------------------------------------------------------
# Problem Session 5
# --------------------------------------------------------------------------------
# Problem Session 6
# --------------------------------------------------------------------------------
# Problem Session 7
# --------------------------------------------------------------------------------
# Problem Session 8
# --------------------------------------------------------------------------------
# Quiz 1 Review
# --------------------------------------------------------------------------------
# Quiz 2 Review
# --------------------------------------------------------------------------------
# Quiz 3 Review
# --------------------------------------------------------------------------------

# %%
with open(file_name, mode='w', encoding='utf-8') as csv_file:
    fieldnames = ['video_name', 'video_url']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for a in soup.find_all('a', attrs={'class' :'resource-list-title'}):
        video_name = a.get_text().strip()
        video_url = 'https://ocw.mit.edu' + a.get('href')
        writer.writerow({'video_name': video_name, 'video_url': video_url})

# %%
pd.read_csv(file_name)
# Out:
#                                            video_name  \
# 0               Lecture 1: Algorithms and Computation
# 1                      Lecture 10: Depth-First Search
# 2                 Lecture 11: Weighted Shortest Paths
# 3                            Lecture 12: Bellman-Ford
# 4                                Lecture 13: Dijkstra
# 5                        Lecture 14: APSP and Johnson
# 6   Lecture 15: Dynamic Programming, Part 1: SRTBO...
# 7   Lecture 16: Dynamic Programming, Part 2: LCS, ...
# 8   Lecture 17: Dynamic Programming, Part 3: APSP,...
# 9   Lecture 18: Dynamic Programming, Part 4: Rods,...
# 10                             Lecture 19: Complexity
# 11      Lecture 2: Data Structures and Dynamic Arrays
# 12                          Lecture 20: Course Review
# 13                Lecture 21: AlgorithmsâNext Steps
# 14                        Lecture 3: Sets and Sorting
# 15                                 Lecture 4: Hashing
# 16                          Lecture 5: Linear Sorting
# 17                    Lecture 6: Binary Trees, Part 1
# 18               Lecture 7: Binary Trees, Part 2: AVL
# 19                            Lecture 8: Binary Heaps
# 20                    Lecture 9: Breadth-First Search
# 21                                  Problem Session 1
# 22                                  Problem Session 2
# 23                                  Problem Session 3
# 24                                  Problem Session 4
# 25                                  Problem Session 5
# 26                                  Problem Session 6
# 27                                  Problem Session 7
# 28                                  Problem Session 8
# 29                                      Quiz 1 Review
# 30                                      Quiz 2 Review
# 31                                      Quiz 3 Review
#
#                                             video_url
# 0   https://ocw.mit.edu/courses/6-006-introduction...
# 1   https://ocw.mit.edu/courses/6-006-introduction...
# 2   https://ocw.mit.edu/courses/6-006-introduction...
# 3   https://ocw.mit.edu/courses/6-006-introduction...
# 4   https://ocw.mit.edu/courses/6-006-introduction...
# 5   https://ocw.mit.edu/courses/6-006-introduction...
# 6   https://ocw.mit.edu/courses/6-006-introduction...
# 7   https://ocw.mit.edu/courses/6-006-introduction...
# 8   https://ocw.mit.edu/courses/6-006-introduction...
# 9   https://ocw.mit.edu/courses/6-006-introduction...
# 10  https://ocw.mit.edu/courses/6-006-introduction...
# 11  https://ocw.mit.edu/courses/6-006-introduction...
# 12  https://ocw.mit.edu/courses/6-006-introduction...
# 13  https://ocw.mit.edu/courses/6-006-introduction...
# 14  https://ocw.mit.edu/courses/6-006-introduction...
# 15  https://ocw.mit.edu/courses/6-006-introduction...
# 16  https://ocw.mit.edu/courses/6-006-introduction...
# 17  https://ocw.mit.edu/courses/6-006-introduction...
# 18  https://ocw.mit.edu/courses/6-006-introduction...
# 19  https://ocw.mit.edu/courses/6-006-introduction...
# 20  https://ocw.mit.edu/courses/6-006-introduction...
# 21  https://ocw.mit.edu/courses/6-006-introduction...
# 22  https://ocw.mit.edu/courses/6-006-introduction...
# 23  https://ocw.mit.edu/courses/6-006-introduction...
# 24  https://ocw.mit.edu/courses/6-006-introduction...
# 25  https://ocw.mit.edu/courses/6-006-introduction...
# 26  https://ocw.mit.edu/courses/6-006-introduction...
# 27  https://ocw.mit.edu/courses/6-006-introduction...
# 28  https://ocw.mit.edu/courses/6-006-introduction...
# 29  https://ocw.mit.edu/courses/6-006-introduction...
# 30  https://ocw.mit.edu/courses/6-006-introduction...
# 31  https://ocw.mit.edu/courses/6-006-introduction...

# %% [markdown]
# ### 4. Scraping Books
# --------------------------------------------------------
#
# 1. Scraping name, price, rate for books and saving this data in csv file.
#
# 2. Scraping Link : https://books.toscrape.com/catalogue/category/books/travel_2/index.html

# %%
response = requests.get('https://books.toscrape.com/catalogue/category/books/travel_2/index.html')

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
title = soup.find('title')
course_name = title.get_text().strip().split('|')[0].strip()
file_name = course_name + '.csv'
file_name
# Out:
# 'Travel.csv'

# %% [markdown]
# ## **Selenium Library**
# Selenium is a powerful tool for controlling web browsers through programs and performing browser automation. It is functional for all browsers, works on all major OS and its scripts are written in various languages i.e Python, Java, C#, etc, we will be working with Python. Selenium Tutorial covers all topics such as – WebDriver, WebElement, Unit Testing with selenium.
#
# ## **Selenim can be used in :**
# 1. Control Browser With Selenium
# 2. Control Browser With Selenium For Automated Testing
# 3. Download File From The Internet
# 4. Scraping Data From Websites as :
#      1. Get Quotes From Websites
#      2. Get Gold and Currencies Rate
#      3. Get News From Websites
#
# **For More Information :** https://www.geeksforgeeks.org/selenium-python-tutorial/
#
# **Note :** this is only intro to selenium and part of selenium library that can be used in web scraping

# %%
#pip install selenium==3.141.0

# %%
#pip install webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import requests
import time
from bs4 import BeautifulSoup

# %%
Path = 'E:\Aslm\Driver\chromedriver.exe'
browser = webdriver.Chrome(Path)
#browser = webdriver.Chrome(ChromeDriverManager().install())

# %%
browser.get('https://www.techwithtim.net/')

# %%
browser.title
# Out:
# 'Tech With Tim - Python & Java Programming Tutorials - techwithtim.net'

# %%
print(browser.page_source)
# Out:
# <html lang="en-US" class=" js csstransforms csstransforms3d csstransitions"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="profile" href="http://gmpg.org/xfn/11"><link rel="pingback" href="https://www.techwithtim.net/xmlrpc.php">  <script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.techwithtim.net&amp;callback=_gfp_s_&amp;client=ca-pub-6240468619130074&amp;gpid_exp=1"></script><script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202207280101/show_ads_impl_fy2021.js?bust=31068684" id="google_shimpl"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-129383985-3"></script> <script>window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-129383985-3');</script> <script>function clicked()
# {
#     alert("Subscriptions coming soon...");
# }</script><meta name="robots" content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1"><link media="all" href="https://www.techwithtim.net/wp-content/cache/autoptimize/css/autoptimize_9ab30a258f1f5f7ff862b60df163e0b2.css" rel="stylesheet"><title>Tech With Tim - Python &amp; Java Programming Tutorials - techwithtim.net</title><meta name="description" content="Python and Java Programming tutorials by Tech With Tim. Featuring pygame game development, machine learning with python &amp; beginner java tutorials"><link rel="canonical" href="https://techwithtim.net/home"><meta property="og:locale" content="en_US"><meta property="og:type" content="website"><meta property="og:title" content="Tech With Tim - Python &amp; Java Programming Tutorials - techwithtim.net"><meta property="og:description" content="Python and Java Programming tutorials by Tech With Tim. Featuring pygame game development, machine learning with python &amp; beginner java tutorials"><meta property="og:url" content="https://techwithtim.net/home"><meta property="og:site_name" content="techwithtim.net"><meta property="article:modified_time" content="2019-02-06T05:35:07+00:00"><meta name="twitter:card" content="summary_large_image"><meta name="twitter:title" content="techwithtimm"><meta name="twitter:site" content="@techwithtimm"><meta name="twitter:label1" content="Est. reading time"><meta name="twitter:data1" content="1 minute"> <script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.techwithtim.net/#website","url":"https://www.techwithtim.net/","name":"techwithtim.net","description":"Programming &amp; Tech Tutorials","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.techwithtim.net/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"WebPage","@id":"https://www.techwithtim.net/","url":"https://techwithtim.net/home","name":"Tech With Tim - Python & Java Programming Tutorials - techwithtim.net","isPartOf":{"@id":"https://www.techwithtim.net/#website"},"datePublished":"2018-11-30T01:16:58+00:00","dateModified":"2019-02-06T05:35:07+00:00","description":"Python and Java Programming tutorials by Tech With Tim. Featuring pygame game development, machine learning with python & beginner java tutorials","breadcrumb":{"@id":"https://techwithtim.net/home#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://techwithtim.net/home"]}]},{"@type":"BreadcrumbList","@id":"https://techwithtim.net/home#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home"}]}]}</script> <link rel="dns-prefetch" href="//fonts.googleapis.com"><link rel="dns-prefetch" href="//s.w.org"><link rel="alternate" type="application/rss+xml" title="techwithtim.net » Feed" href="https://www.techwithtim.net/feed/"><link rel="alternate" type="application/rss+xml" title="techwithtim.net » Comments Feed" href="https://www.techwithtim.net/comments/feed/"> <script type="text/javascript">window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.techwithtim.net\/wp-includes\/js\/wp-emoji-release.min.js?ver=6.0.1"}};
# /*! This file is auto-generated */
# !function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode,e=(p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0),i.toDataURL());return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([129777,127995,8205,129778,127999],[129777,127995,8203,129778,127999])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(e=t.source||{}).concatemoji?c(e.concatemoji):e.wpemoji&&e.twemoji&&(c(e.twemoji),c(e.wpemoji)))}(window,document,window._wpemojiSettings);</script><script src="https://www.techwithtim.net/wp-includes/js/wp-emoji-release.min.js?ver=6.0.1" type="text/javascript" defer=""></script> <link rel="stylesheet" id="simpel-title-font-css" href="//fonts.googleapis.com/css?family=Roboto%3A100%2C300%2C400%2C700&amp;ver=6.0.1" type="text/css" media="all"><link rel="stylesheet" id="simpel-body-font-css" href="//fonts.googleapis.com/css?family=Roboto%3A100%2C300%2C400%2C700&amp;ver=6.0.1" type="text/css" media="all"> <script type="text/javascript" src="https://www.techwithtim.net/wp-includes/js/jquery/jquery.min.js?ver=3.6.0" id="jquery-core-js"></script> <script type="text/javascript" id="fts_clear_cache_script-js-extra">var ftsAjax = {"ajaxurl":"https:\/\/www.techwithtim.net\/wp-admin\/admin-ajax.php"};
# var ftsAjax = {"ajaxurl":"https:\/\/www.techwithtim.net\/wp-admin\/admin-ajax.php"};</script> <script type="text/javascript" id="fts_encrypt_script-js-extra">var ftsAjaxEncrypt = {"ajaxurl":"https:\/\/www.techwithtim.net\/wp-admin\/admin-ajax.php","nonce":"494db2a762"};
# var ftsAjaxEncrypt = {"ajaxurl":"https:\/\/www.techwithtim.net\/wp-admin\/admin-ajax.php","nonce":"494db2a762"};</script> <script type="text/javascript" id="fts-global-js-extra">var fts_twitter_ajax = {"ajax_url":"https:\/\/www.techwithtim.net\/wp-admin\/admin-ajax.php"};
# var fts_twitter_ajax = {"ajax_url":"https:\/\/www.techwithtim.net\/wp-admin\/admin-ajax.php"};</script> <link rel="https://api.w.org/" href="https://www.techwithtim.net/wp-json/"><link rel="alternate" type="application/json" href="https://www.techwithtim.net/wp-json/wp/v2/pages/6"><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://www.techwithtim.net/xmlrpc.php?rsd"><link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://www.techwithtim.net/wp-includes/wlwmanifest.xml"><meta name="generator" content="WordPress 6.0.1"><link rel="shortlink" href="https://www.techwithtim.net/"><link rel="alternate" type="application/json+oembed" href="https://www.techwithtim.net/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.techwithtim.net%2F"><link rel="alternate" type="text/xml+oembed" href="https://www.techwithtim.net/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.techwithtim.net%2F&amp;format=xml"><style type="text/css">.header-image {
# 			background: url(https://techwithtim.net/wp-content/uploads/2020/02/cropped-Webp.net-resizeimage.png) no-repeat 50% 50%;
# 			-webkit-background-size: cover;
# 			-moz-background-size:    cover;
# 			-o-background-size:      cover;
# 			background-size:         cover;
# 		}
#
# 		@media screen and (min-width: 59.6875em) {
# 			body:before {
# 				background: url(https://techwithtim.net/wp-content/uploads/2020/02/cropped-Webp.net-resizeimage.png) no-repeat 100% 50%;
# 				-webkit-background-size: cover;
# 				-moz-background-size:    cover;
# 				-o-background-size:      cover;
# 				background-size:         cover;
# 				border-right: 0;
# 			}
#
# 			.site-header {
# 				background: transparent;
# 			}
# 		}</style><link rel="icon" href="https://www.techwithtim.net/wp-content/uploads/2020/02/cropped-Tech-With-TimXL-32x32.png" sizes="32x32"><link rel="icon" href="https://www.techwithtim.net/wp-content/uploads/2020/02/cropped-Tech-With-TimXL-192x192.png" sizes="192x192"><link rel="apple-touch-icon" href="https://www.techwithtim.net/wp-content/uploads/2020/02/cropped-Tech-With-TimXL-180x180.png"><meta name="msapplication-TileImage" content="https://www.techwithtim.net/wp-content/uploads/2020/02/cropped-Tech-With-TimXL-270x270.png"><link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.6.0/css/all.css" integrity="sha384-aOkxzJ5uQz7WBObEZcHvV5JvRW3TUc2rNPA7pe3AwnsUohiw1Vj2Rgx2KSOkF5+h" crossorigin="anonymous"><meta name="google-site-verification" content="Klz-majLq2UU1MPxJLTwwrCBRgin6tHkBkqiIx8eaPA"><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><link rel="preload" href="https://adservice.google.com.eg/adsid/integrator.js?domain=www.techwithtim.net" as="script"><script type="text/javascript" src="https://adservice.google.com.eg/adsid/integrator.js?domain=www.techwithtim.net"></script><link rel="preload" href="https://adservice.google.com/adsid/integrator.js?domain=www.techwithtim.net" as="script"><script type="text/javascript" src="https://adservice.google.com/adsid/integrator.js?domain=www.techwithtim.net"></script></head><body class="home page-template-default page page-id-6 siteorigin-panels siteorigin-panels-home fts-powered-by-text-popup"><div class="slicknav_menu"><a href="#" aria-haspopup="true" tabindex="0" class="slicknav_btn slicknav_collapsed" style="outline: none;"><span class="slicknav_menutxt">MENU</span><span class="slicknav_icon"><span class="slicknav_icon-bar"></span><span class="slicknav_icon-bar"></span><span class="slicknav_icon-bar"></span></span></a><ul class="slicknav_nav slicknav_hidden" aria-expanded="false" style="display: none;" aria-hidden="true" role="menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home current-menu-item page_item page-item-6 current_page_item menu-item-156"><a href="https://www.techwithtim.net/" aria-current="page" role="menuitem" tabindex="-1">Home</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-25"><a title="tutorials" href="https://www.techwithtim.net/tutorials/" role="menuitem" tabindex="-1">Tutorials</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28"><a title="community" href="https://www.techwithtim.net/community/" role="menuitem" tabindex="-1">Community</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2262"><a href="https://www.techwithtim.net/gear/" role="menuitem" tabindex="-1">My Gear</a></li><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3153"><a href="https://teespring.com/stores/tech-with-tim-merch-shop" role="menuitem" tabindex="-1">Shop</a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-26"><a title="support" href="https://www.techwithtim.net/support ...

# %%
type(browser.page_source)
# Out:
# str

# %%
search = browser.find_element_by_name('s')
search.clear()
search.send_keys('test')
search.send_keys(Keys.RETURN)

# %%
home = browser.find_element_by_id('text-title-desc').find_element_by_tag_name('a')
home.click()
time.sleep(3)
python = browser.find_element_by_link_text('Python Programming')
python.click()

# %%
browser.back()
time.sleep(1)

# %%
browser.forward()
time.sleep(1)

# %%
browser.back()
time.sleep(1)

# %%
search = browser.find_element_by_name('s')
search.clear()
search.send_keys('python')
search.send_keys(Keys.RETURN)

# %%
main = browser.find_element_by_id('main')
headers = main.find_elements_by_class_name('entry-title')

for header in headers :
        text_tag = header.find_element_by_tag_name('a')
        print(text_tag.get_attribute('text'))
        print(text_tag.get_attribute('href'))
        print('--'*50)
# Out:
# Python AI ChatBot Tutorial
# https://www.techwithtim.net/tutorials/ai-chatbot/
# ----------------------------------------------------------------------------------------------------
# Python Neural Networks
# https://www.techwithtim.net/tutorials/python-neural-networks/
# ----------------------------------------------------------------------------------------------------
# Sending Emails with Python
# https://www.techwithtim.net/tutorials/sending-emails-with-python/
# ----------------------------------------------------------------------------------------------------
# Python Multi-Threading Tutorials
# https://www.techwithtim.net/tutorials/python-programming/python-multi-threading/
# ----------------------------------------------------------------------------------------------------
# Google Sheets – Python API Tutorial
# https://www.techwithtim.net/tutorials/google-sheets-python-api-tutorial/
# ----------------------------------------------------------------------------------------------------
# Python Online Game Tutorial
# https://www.techwithtim.net/tutorials/python-online-game-tutorial/
# ----------------------------------------------------------------------------------------------------
# Python Path Finding with Breadth First Search
# https://www.techwithtim.net/tutorials/breadth-first-search/
# ----------------------------------------------------------------------------------------------------
# Machine Learning With Python
# https://www.techwithtim.net/tutorials/machine-learning-python/
# ----------------------------------------------------------------------------------------------------
# Intermediate Python Tutorials
# https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/
# ----------------------------------------------------------------------------------------------------
# Beginner Python Tutorials
# https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/
# ----------------------------------------------------------------------------------------------------

# %%
i = 1
while True :
        main = browser.find_element_by_id('main')
        headers = main.find_elements_by_class_name('entry-title')
        print('Page ' + str(i))
        print('--------')
        print('\n')
        for header in headers :
                text_tag = header.find_element_by_tag_name('a')
                print('\tName :'+ text_tag.get_attribute('text'))
                print('\t' + text_tag.get_attribute('href'))
                print('--'*50)
        try :         
            browser.find_element_by_link_text('Next →').click()
            i += 1
            print('\n\n')
            print('\tTo Next Page\n\n')
            time.sleep(2)
        except : 
            break
# Out:
# Page 1
# --------
#
#
# 	Name :Python AI ChatBot Tutorial
# 	https://www.techwithtim.net/tutorials/ai-chatbot/
# ----------------------------------------------------------------------------------------------------
# 	Name :Python Neural Networks
# 	https://www.techwithtim.net/tutorials/python-neural-networks/
# ----------------------------------------------------------------------------------------------------
# 	Name :Sending Emails with Python
# 	https://www.techwithtim.net/tutorials/sending-emails-with-python/
# ----------------------------------------------------------------------------------------------------
# 	Name :Python Multi-Threading Tutorials
# 	https://www.techwithtim.net/tutorials/python-programming/python-multi-threading/
# ----------------------------------------------------------------------------------------------------
# 	Name :Google Sheets – Python API Tutorial
# 	https://www.techwithtim.net/tutorials/google-sheets-python-api-tutorial/
# ----------------------------------------------------------------------------------------------------
# 	Name :Python Online Game Tutorial
# 	https://www.techwithtim.net/tutorials/python-online-game-tutorial/
# ----------------------------------------------------------------------------------------------------
# 	Name :Python Path Finding with Breadth First Search
# 	https://www.techwithtim.net/tutorials/breadth-first-search/
# ----------------------------------------------------------------------------------------------------
# 	Name :Machine Learning With Python
# 	https://www.techwithtim.net/tutorials/machine-learning-python/
# ----------------------------------------------------------------------------------------------------
# 	Name :Intermediate Python Tutorials
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/
# ----------------------------------------------------------------------------------------------------
# 	Name :Beginner Python Tutorials
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 2
# --------
#
#
# 	Name :Python Module Walk-Through’s
# 	https://www.techwithtim.net/tutorials/python-module-walk-throughs/
# ----------------------------------------------------------------------------------------------------
# 	Name :Python Programming
# 	https://www.techwithtim.net/tutorials/python-programming/
# ----------------------------------------------------------------------------------------------------
# 	Name :Game Development With Python
# 	https://www.techwithtim.net/tutorials/game-development-with-python/
# ----------------------------------------------------------------------------------------------------
# 	Name :Sessions
# 	https://www.techwithtim.net/tutorials/flask/sessions/
# ----------------------------------------------------------------------------------------------------
# 	Name :HTTP Methods – GET & POST
# 	https://www.techwithtim.net/tutorials/flask/http-methods-get-post/
# ----------------------------------------------------------------------------------------------------
# 	Name :HTML Templates
# 	https://www.techwithtim.net/tutorials/flask/html-templates/
# ----------------------------------------------------------------------------------------------------
# 	Name :A Basic Website
# 	https://www.techwithtim.net/tutorials/flask/a-basic-website/
# ----------------------------------------------------------------------------------------------------
# 	Name :Flask Web Development
# 	https://www.techwithtim.net/tutorials/flask/
# ----------------------------------------------------------------------------------------------------
# 	Name :Wake Keyword
# 	https://www.techwithtim.net/tutorials/voice-assistant/wake-keyword/
# ----------------------------------------------------------------------------------------------------
# 	Name :Opening Programs
# 	https://www.techwithtim.net/tutorials/voice-assistant/opening-programs/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 3
# --------
#
#
# 	Name :Events by Day
# 	https://www.techwithtim.net/tutorials/voice-assistant/events-by-day/
# ----------------------------------------------------------------------------------------------------
# 	Name :Google Calendar Setup
# 	https://www.techwithtim.net/tutorials/voice-assistant/google-calendar-setup/
# ----------------------------------------------------------------------------------------------------
# 	Name :Getting Microphone Input
# 	https://www.techwithtim.net/tutorials/voice-assistant/getting-microphone-input/
# ----------------------------------------------------------------------------------------------------
# 	Name :Playing Sound
# 	https://www.techwithtim.net/tutorials/voice-assistant/playing-sound/
# ----------------------------------------------------------------------------------------------------
# 	Name :Voice Assistant Tutorial
# 	https://www.techwithtim.net/tutorials/voice-assistant/
# ----------------------------------------------------------------------------------------------------
# 	Name :ComboBoxes
# 	https://www.techwithtim.net/tutorials/pyqt5-tutorial/comboboxes/
# ----------------------------------------------------------------------------------------------------
# 	Name :Images/QPixmap
# 	https://www.techwithtim.net/tutorials/pyqt5-tutorial/images/
# ----------------------------------------------------------------------------------------------------
# 	Name :Menubar
# 	https://www.techwithtim.net/tutorials/pyqt5-tutorial/menubar/
# ----------------------------------------------------------------------------------------------------
# 	Name :How to Use QtDesigner
# 	https://www.techwithtim.net/tutorials/pyqt5-tutorial/how-to-use-qtdesigner/
# ----------------------------------------------------------------------------------------------------
# 	Name :Buttons and Events
# 	https://www.techwithtim.net/tutorials/pyqt5-tutorial/buttons-and-events/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 4
# --------
#
#
# 	Name :Basic GUI Application
# 	https://www.techwithtim.net/tutorials/pyqt5-tutorial/basic-gui-application/
# ----------------------------------------------------------------------------------------------------
# 	Name :PyQt5 Tutorial
# 	https://www.techwithtim.net/tutorials/pyqt5-tutorial/
# ----------------------------------------------------------------------------------------------------
# 	Name :Part 3
# 	https://www.techwithtim.net/tutorials/ai-chatbot/part-3/
# ----------------------------------------------------------------------------------------------------
# 	Name :Part 1
# 	https://www.techwithtim.net/tutorials/ai-chatbot/part-1/
# ----------------------------------------------------------------------------------------------------
# 	Name :Text Classification P4
# 	https://www.techwithtim.net/tutorials/python-neural-networks/text-classification-p4/
# ----------------------------------------------------------------------------------------------------
# 	Name :Looking at and Loading Data
# 	https://www.techwithtim.net/tutorials/python-neural-networks/loading-data/
# ----------------------------------------------------------------------------------------------------
# 	Name :User Specific Pages & Data
# 	https://www.techwithtim.net/tutorials/django/user-specific-pages-data/
# ----------------------------------------------------------------------------------------------------
# 	Name :User Registration & Sign Up
# 	https://www.techwithtim.net/tutorials/django/user-registration/
# ----------------------------------------------------------------------------------------------------
# 	Name :Simple Forms
# 	https://www.techwithtim.net/tutorials/django/simple-forms/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tree Data Structure
# 	https://www.techwithtim.net/tutorials/tree-data-structure/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 5
# --------
#
#
# 	Name :HTML Templates
# 	https://www.techwithtim.net/tutorials/django/html-templates/
# ----------------------------------------------------------------------------------------------------
# 	Name :Admin Page
# 	https://www.techwithtim.net/tutorials/django/admin-page/
# ----------------------------------------------------------------------------------------------------
# 	Name :SQLite3 Database Setup
# 	https://www.techwithtim.net/tutorials/django/sqlite3-database/
# ----------------------------------------------------------------------------------------------------
# 	Name :Setup, Installation & Page Navigation
# 	https://www.techwithtim.net/tutorials/django/setup/
# ----------------------------------------------------------------------------------------------------
# 	Name :Django Tutorial
# 	https://www.techwithtim.net/tutorials/django/
# ----------------------------------------------------------------------------------------------------
# 	Name :Sudoku Solver w/ Backtracking
# 	https://www.techwithtim.net/tutorials/python-programming/sudoku-solver-backtracking/
# ----------------------------------------------------------------------------------------------------
# 	Name :Synchronizing and Locking Threads
# 	https://www.techwithtim.net/tutorials/python-programming/python-multi-threading/synchronizing-and-locking-threads/
# ----------------------------------------------------------------------------------------------------
# 	Name :Sending Objects
# 	https://www.techwithtim.net/tutorials/python-online-game-tutorial/sending-objects/
# ----------------------------------------------------------------------------------------------------
# 	Name :Connecting Multiple Clients
# 	https://www.techwithtim.net/tutorials/python-online-game-tutorial/connecting-multiple-clients/
# ----------------------------------------------------------------------------------------------------
# 	Name :Navigation Between Multiple Screens
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/multiple-screens/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 6
# --------
#
#
# 	Name :Touch Input/Mouse Input
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/touch-input-mouse-input/
# ----------------------------------------------------------------------------------------------------
# 	Name :FloatLayout for Dynamic Placement
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/floatlayout/
# ----------------------------------------------------------------------------------------------------
# 	Name :Object Properties and .kv Continued
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/object-properties/
# ----------------------------------------------------------------------------------------------------
# 	Name :The kv Design Language (.kv File)
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/the-kv-design-language-kv-file/
# ----------------------------------------------------------------------------------------------------
# 	Name :Labels, Input and GUI Layouts
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/gui-layouts/
# ----------------------------------------------------------------------------------------------------
# 	Name :Setup/Creating A Simple Application
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/setup/
# ----------------------------------------------------------------------------------------------------
# 	Name :Kivy Tutorials
# 	https://www.techwithtim.net/tutorials/kivy-tutorial/
# ----------------------------------------------------------------------------------------------------
# 	Name :Hosting a Discord Bot for Free
# 	https://www.techwithtim.net/tutorials/discord-py/hosting-a-discord-bot-for-free/
# ----------------------------------------------------------------------------------------------------
# 	Name :Setup and Introduction
# 	https://www.techwithtim.net/tutorials/discord-py/setup/
# ----------------------------------------------------------------------------------------------------
# 	Name :Discord.py Tutorials
# 	https://www.techwithtim.net/tutorials/discord-py/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 7
# --------
#
#
# 	Name :K Means Clustering P.1 – How it Works
# 	https://www.techwithtim.net/tutorials/machine-learning-python/k-means-1/
# ----------------------------------------------------------------------------------------------------
# 	Name :SVM P.1 – Loading Sklearn Datasets
# 	https://www.techwithtim.net/tutorials/machine-learning-python/svm-1/
# ----------------------------------------------------------------------------------------------------
# 	Name :KNN P.2 – How Does it Work?
# 	https://www.techwithtim.net/tutorials/machine-learning-python/k-nearest-neighbors-2/
# ----------------------------------------------------------------------------------------------------
# 	Name :KNN P.1 – Irregular Data
# 	https://www.techwithtim.net/tutorials/machine-learning-python/k-nearest-neighbors-1/
# ----------------------------------------------------------------------------------------------------
# 	Name :Introduction
# 	https://www.techwithtim.net/tutorials/java-programming/introduction/
# ----------------------------------------------------------------------------------------------------
# 	Name :Saving & Training Multiple Models
# 	https://www.techwithtim.net/tutorials/machine-learning-python/saving-models/
# ----------------------------------------------------------------------------------------------------
# 	Name :Linear Regression P.2
# 	https://www.techwithtim.net/tutorials/machine-learning-python/linear-regression-2/
# ----------------------------------------------------------------------------------------------------
# 	Name :Introduction & Setup
# 	https://www.techwithtim.net/tutorials/machine-learning-python/introduction/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tic Tac Toe Tutorial
# 	https://www.techwithtim.net/tutorials/python-programming/tic-tac-toe-tutorial/
# ----------------------------------------------------------------------------------------------------
# 	Name :Private and Public Classes
# 	https://www.techwithtim.net/tutorials/python-programming/classes-objects-in-python/private-and-public-classes/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 8
# --------
#
#
# 	Name :Overloading Methods
# 	https://www.techwithtim.net/tutorials/python-programming/classes-objects-in-python/overloading-methods/
# ----------------------------------------------------------------------------------------------------
# 	Name :Inheritance
# 	https://www.techwithtim.net/tutorials/python-programming/classes-objects-in-python/inheritance/
# ----------------------------------------------------------------------------------------------------
# 	Name :Introduction to Objects
# 	https://www.techwithtim.net/tutorials/python-programming/classes-objects-in-python/introduction-to-objects/
# ----------------------------------------------------------------------------------------------------
# 	Name :Classes & Objects Tutorials
# 	https://www.techwithtim.net/tutorials/python-programming/classes-objects-in-python/
# ----------------------------------------------------------------------------------------------------
# 	Name :Collections/namedtuple()
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/collections-namedtuple/
# ----------------------------------------------------------------------------------------------------
# 	Name :Collections/Counter()
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/collections-counter/
# ----------------------------------------------------------------------------------------------------
# 	Name :Lambda Functions
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/lambda-functions/
# ----------------------------------------------------------------------------------------------------
# 	Name :Filter() Function
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/filter-function/
# ----------------------------------------------------------------------------------------------------
# 	Name :Map() Function
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/map-function/
# ----------------------------------------------------------------------------------------------------
# 	Name :Static & Class Methods
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/static-class-methods/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 9
# --------
#
#
# 	Name :Optional Parameters
# 	https://www.techwithtim.net/tutorials/python-programming/intermediate-python-tutorials/optional-parameters/
# ----------------------------------------------------------------------------------------------------
# 	Name :Classes and Objects
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/classes-and-objects/
# ----------------------------------------------------------------------------------------------------
# 	Name :Global vs Local
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/global-vs-local/
# ----------------------------------------------------------------------------------------------------
# 	Name :Error Handling (Try/Except)
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/error-handling-try-except/
# ----------------------------------------------------------------------------------------------------
# 	Name :Introduction to Modular Programming
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/introduction-to-modular-programming/
# ----------------------------------------------------------------------------------------------------
# 	Name :List Methods (.count/.find)
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/list-methods-count-find/
# ----------------------------------------------------------------------------------------------------
# 	Name :File IO(Writing Files)
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/file-iowriting-files/
# ----------------------------------------------------------------------------------------------------
# 	Name :File IO (Reading Files)
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/file-io-reading-files/
# ----------------------------------------------------------------------------------------------------
# 	Name :Functions
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/functions/
# ----------------------------------------------------------------------------------------------------
# 	Name :Slice Operator
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/slice-operator/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 10
# --------
#
#
# 	Name :String Methods
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/string-methods/
# ----------------------------------------------------------------------------------------------------
# 	Name :Iteration by Item (For Loops Continued)
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/iteration-by-item-for-loops-continued/
# ----------------------------------------------------------------------------------------------------
# 	Name :Lists and Tuples
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/lists-and-tuples/
# ----------------------------------------------------------------------------------------------------
# 	Name :While Loops
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/while-loops/
# ----------------------------------------------------------------------------------------------------
# 	Name :For Loops
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/for-loops/
# ----------------------------------------------------------------------------------------------------
# 	Name :Chained Conditionals & Nested Statements
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/chained-conditionals-nested-statements/
# ----------------------------------------------------------------------------------------------------
# 	Name :IF/ELIF/ELSE
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/if-elif-else/
# ----------------------------------------------------------------------------------------------------
# 	Name :Conditions
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/conditions/
# ----------------------------------------------------------------------------------------------------
# 	Name :Basic Operators & Input
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/basic-operators-input/
# ----------------------------------------------------------------------------------------------------
# 	Name :Variables & Data Types
# 	https://www.techwithtim.net/tutorials/python-programming/beginner-python-tutorials/variables-data-types/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 11
# --------
#
#
# 	Name :Shapes and Fills
# 	https://www.techwithtim.net/tutorials/python-module-walk-throughs/turtle-module/shapes-and-fills/
# ----------------------------------------------------------------------------------------------------
# 	Name :Introduction
# 	https://www.techwithtim.net/tutorials/python-module-walk-throughs/turtle-module/introduction/
# ----------------------------------------------------------------------------------------------------
# 	Name :Array Creation
# 	https://www.techwithtim.net/tutorials/python-module-walk-throughs/numpy-module/array-creation/
# ----------------------------------------------------------------------------------------------------
# 	Name :Introduction
# 	https://www.techwithtim.net/tutorials/python-module-walk-throughs/numpy-module/introduction/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tutorial #3
# 	https://www.techwithtim.net/tutorials/game-development-with-python/tetris-pygame/tutorial-3/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tutorial #2
# 	https://www.techwithtim.net/tutorials/game-development-with-python/tetris-pygame/tutorial-2/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tutorial #1
# 	https://www.techwithtim.net/tutorials/game-development-with-python/tetris-pygame/tutorial-1/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tutorial #4
# 	https://www.techwithtim.net/tutorials/game-development-with-python/snake-pygame/tutorial-4/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tutorial #3
# 	https://www.techwithtim.net/tutorials/game-development-with-python/snake-pygame/tutorial-3/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tutorial #2
# 	https://www.techwithtim.net/tutorials/game-development-with-python/snake-pygame/tutorial-2/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 12
# --------
#
#
# 	Name :Tutorial #1
# 	https://www.techwithtim.net/tutorials/game-development-with-python/snake-pygame/tutorial-1/
# ----------------------------------------------------------------------------------------------------
# 	Name :Scoring & End Screen
# 	https://www.techwithtim.net/tutorials/game-development-with-python/side-scroller-pygame/scoring-end-screen/
# ----------------------------------------------------------------------------------------------------
# 	Name :Scrolling Background & Character Movement
# 	https://www.techwithtim.net/tutorials/game-development-with-python/side-scroller-pygame/background/
# ----------------------------------------------------------------------------------------------------
# 	Name :Finishing Touches
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/pygame-tutorial/
# ----------------------------------------------------------------------------------------------------
# 	Name :Sound Effects & Music
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/sound-effects-music/
# ----------------------------------------------------------------------------------------------------
# 	Name :Scoring & Health Bars
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/scoring-health-bars/
# ----------------------------------------------------------------------------------------------------
# 	Name :Collision & Hit Boxes
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/pygame-collision/
# ----------------------------------------------------------------------------------------------------
# 	Name :Enemies
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/pygame-enemies/
# ----------------------------------------------------------------------------------------------------
# 	Name :Character Animation & Sprites
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/pygame-animation/
# ----------------------------------------------------------------------------------------------------
# 	Name :Basic Movement & Key Presses
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/pygame-tutorial-movement/
# ----------------------------------------------------------------------------------------------------
#
#
#
# 	To Next Page
#
#
# Page 13
# --------
#
#
# 	Name :Tetris Tutorial
# 	https://www.techwithtim.net/tutorials/game-development-with-python/tetris-pygame/
# ----------------------------------------------------------------------------------------------------
# 	Name :General Pygame Tutorial
# 	https://www.techwithtim.net/tutorials/game-development-with-python/pygame-tutorial/
# ----------------------------------------------------------------------------------------------------
# 	Name :Side-Scroller Tutorial
# 	https://www.techwithtim.net/tutorials/game-development-with-python/side-scroller-pygame/
# ----------------------------------------------------------------------------------------------------
# 	Name :Snake Tutorial
# 	https://www.techwithtim.net/tutorials/game-development-with-python/snake-pygame/
# ----------------------------------------------------------------------------------------------------
# 	Name :Turtle Module
# 	https://www.techwithtim.net/tutorials/python-module-walk-throughs/turtle-module/
# ----------------------------------------------------------------------------------------------------
# 	Name :Numpy Module
# 	https://www.techwithtim.net/tutorials/python-module-walk-throughs/numpy-module/
# ----------------------------------------------------------------------------------------------------
# 	Name :Tutorials & Guides
# 	https://www.techwithtim.net/tutorials/
# ----------------------------------------------------------------------------------------------------
# 	Name :Home
# 	https://www.techwithtim.net/
# ----------------------------------------------------------------------------------------------------

# %%
browser.quit()

# %%
frist_travel_book = soup.find('article',  attrs = {'class':'product_pod'})
frist_travel_book
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="../../../its-only-the-himalayas_981/index.html"><img alt="It's Only the Himalayas" class="thumbnail" src="../../../../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/></a>
# </div>
# <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>
# <div class="product_price">
# <p class="price_color">Â£45.17</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
frist_travel_book_name = frist_travel_book.find('h3').get_text().strip()
frist_travel_book_name
# Out:
# "It's Only the Himalayas"

# %%
frist_travel_book_rating = frist_travel_book.find('p', attrs = {'class':'star-rating'}).get('class')[1]
frist_travel_book_rating
# Out:
# 'Two'

# %%
frist_travel_book_price = frist_travel_book.find('div', attrs = {'class':'product_price'}).find('p',{'class' :"price_color"})
frist_travel_book_price = float(frist_travel_book_price.get_text().split('Â£')[1])
frist_travel_book_price
# Out:
# 45.17

# %%
travel_books = soup.find_all('article',  attrs = {'class':'product_pod'})
travel_books
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="../../../its-only-the-himalayas_981/index.html"><img alt="It's Only the Himalayas" class="thumbnail" src="../../../../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/></a>
#  </div>
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£45.17</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html"><img alt="Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond" class="thumbnail" src="../../../../media/cache/57/77/57770cac1628f4407636635f4b85e88c.jpg"/></a>
#  </div>
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html" title="Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond">Full Moon over Noahâs ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£49.43</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html"><img alt="See America: A Celebration of Our National Parks &amp; Treasured Sites" class="thumbnail" src="../../../../media/cache/9a/7e/9a7e63f12829df4b43b31d110bf3dc2e.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html" title="See America: A Celebration of Our National Parks &amp; Treasured Sites">See America: A Celebration ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£48.87</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html"><img alt="Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel" class="thumbnail" src="../../../../media/cache/d5/bf/d5bf0090470b0b8ea46d9c166f7895aa.jpg"/></a>
#  </div>
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html" title="Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel">Vagabonding: An Uncommon Guide ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£36.94</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../under-the-tuscan-sun_504/index.html"><img alt="Under the Tuscan Sun" class="thumbnail" src="../../../../media/cache/98/c2/98c2e95c5fd1a4e7cd5f2b63c52826cb.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../under-the-tuscan-sun_504/index.html" title="Under the Tuscan Sun">Under the Tuscan Sun</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£37.33</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../a-summer-in-europe_458/index.html"><img alt="A Summer In Europe" class="thumbnail" src="../../../../media/cache/4e/15/4e15150388702ebca2c5a523ac270539.jpg"/></a>
#  </div>
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../a-summer-in-europe_458/index.html" title="A Summer In Europe">A Summer In Europe</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£44.34</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../the-great-railway-bazaar_446/index.html"><img alt="The Great Railway Bazaar" class="thumbnail" src="../../../../media/cache/76/de/76de41867f323d7f1f4fbe2fdfc1b2ba.jpg"/></a>
#  </div>
#  <p class="star-rating One">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../the-great-railway-bazaar_446/index.html" title="The Great Railway Bazaar">The Great Railway Bazaar</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£30.54</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../a-year-in-provence-provence-1_421/index.html"><img alt="A Year in Provence (Provence #1)" class="thumbnail" src="../../../../media/cache/db/46/db46159b05faa5d95262112bf9c29ddd.jpg"/></a>
#  </div>
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../a-year-in-provence-provence-1_421/index.html" title="A Year in Provence (Provence #1)">A Year in Provence ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£56.88</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html"><img alt="The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)" class="thumbnail" src="../../../../media/cache/e0/4f/e04f8eda2a2fa947aec17640202d9ab0.jpg"/></a>
#  </div>
#  <p class="star-rating One">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html" title="The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)">The Road to Little ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£23.21</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../neither-here-nor-there-travels-in-europe_198/index.html"><img alt="Neither Here nor There: Travels in Europe" class="thumbnail" src="../../../../media/cache/06/81/0681530a7bc301caf5c3257e1b0f0750.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../neither-here-nor-there-travels-in-europe_198/index.html" title="Neither Here nor There: Travels in Europe">Neither Here nor There: ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£38.95</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../1000-places-to-see-before-you-die_1/index.html"><img alt="1,000 Places to See Before You Die" class="thumbnail" src="../../../../media/cache/d7/0f/d70f7edd92705c45a82118c3ff6c299d.jpg"/></a>
#  </div>
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../1000-places-to-see-before-you-die_1/index.html" title="1,000 Places to See Before You Die">1,000 Places to See ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£26.08</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>]

# %%
len(travel_books)
# Out:
# 11

# %%
for book in travel_books :
    travel_book_name = book.find('h3').get_text().strip()
    rates = {'One' : 1 , 'Two' : 2 , 'Three' : 3 , 'Four' : 4 , 'Five' : 5}
    travel_book_rating = rates[book.find('p', attrs = {'class':'star-rating'}).get('class')[1]]
    travel_book_price = book.find('div', attrs = {'class':'product_price'}).find('p',{'class' :"price_color"})
    travel_book_price = float(travel_book_price.get_text().split('Â£')[1])
    print(f'Name : {travel_book_name} ||  Rating : {travel_book_rating} || Price :{travel_book_price}')
    print('---'*40)
# Out:
# Name : It's Only the Himalayas ||  Rating : 2 || Price :45.17
# ------------------------------------------------------------------------------------------------------------------------
# Name : Full Moon over Noahâs ... ||  Rating : 4 || Price :49.43
# ------------------------------------------------------------------------------------------------------------------------
# Name : See America: A Celebration ... ||  Rating : 3 || Price :48.87
# ------------------------------------------------------------------------------------------------------------------------
# Name : Vagabonding: An Uncommon Guide ... ||  Rating : 2 || Price :36.94
# ------------------------------------------------------------------------------------------------------------------------
# Name : Under the Tuscan Sun ||  Rating : 3 || Price :37.33
# ------------------------------------------------------------------------------------------------------------------------
# Name : A Summer In Europe ||  Rating : 2 || Price :44.34
# ------------------------------------------------------------------------------------------------------------------------
# Name : The Great Railway Bazaar ||  Rating : 1 || Price :30.54
# ------------------------------------------------------------------------------------------------------------------------
# Name : A Year in Provence ... ||  Rating : 4 || Price :56.88
# ------------------------------------------------------------------------------------------------------------------------
# Name : The Road to Little ... ||  Rating : 1 || Price :23.21
# ------------------------------------------------------------------------------------------------------------------------
# Name : Neither Here nor There: ... ||  Rating : 3 || Price :38.95
# ------------------------------------------------------------------------------------------------------------------------
# Name : 1,000 Places to See ... ||  Rating : 5 || Price :26.08
# ------------------------------------------------------------------------------------------------------------------------

# %%
with open(file_name, mode='w', encoding='utf-8') as csv_file:
    fieldnames = ['Book Name', 'Book Rating' , 'Book Price']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for book in travel_books :
        travel_book_name = book.find('h3').get_text().strip()
        rates = {'One' : 1 , 'Two' : 2 , 'Three' : 3 , 'Four' : 4 , 'Five' : 5}
        travel_book_rating = rates[book.find('p', attrs = {'class':'star-rating'}).get('class')[1]]
        travel_book_price = book.find('div', attrs = {'class':'product_price'}).find('p',{'class' :"price_color"})
        travel_book_price = float(travel_book_price.get_text().split('Â£')[1]) 
        writer.writerow({'Book Name': travel_book_name, 'Book Rating': travel_book_rating 
                        , 'Book Price' :travel_book_price})

# %%
df = pd.read_csv(file_name)
df
# Out:
#                              Book Name  Book Rating  Book Price
# 0              It's Only the Himalayas            2       45.17
# 1          Full Moon over Noahâs ...            4       49.43
# 2       See America: A Celebration ...            3       48.87
# 3   Vagabonding: An Uncommon Guide ...            2       36.94
# 4                 Under the Tuscan Sun            3       37.33
# 5                   A Summer In Europe            2       44.34
# 6             The Great Railway Bazaar            1       30.54
# 7               A Year in Provence ...            4       56.88
# 8               The Road to Little ...            1       23.21
# 9          Neither Here nor There: ...            3       38.95
# 10             1,000 Places to See ...            5       26.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Book Name    11 non-null     object
#  1   Book Rating  11 non-null     int64
#  2   Book Price   11 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 392.0+ bytes

# %%
df.describe()
# Out:
#        Book Rating  Book Price
# count    11.000000   11.000000
# mean      2.727273   39.794545
# std       1.272078   10.394198
# min       1.000000   23.210000
# 25%       2.000000   33.740000
# 50%       3.000000   38.950000
# 75%       3.500000   47.020000
# max       5.000000   56.880000

# %%
response = requests.get('https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html')
soup = BeautifulSoup(response.text, 'html.parser')

file_name = soup.find('title').get_text().strip().split(' | ')[0]
file_name += '.csv'

rates = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}

with open(file_name, mode='w', encoding='utf-8') as csv_file:
    fieldnames = ['book_name', 'book_price', 'book_rate']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for article in soup.find_all('article', attrs={'class': 'product_pod'}):
        book_name = article.find('h3').find('a').get('title')
        book_price = float(article.find('p', attrs={'class': 'price_color'}).get_text()[2:])
        book_rate = rates[article.find('p', attrs={'class': 'star-rating'}).get('class')[-1]]
        writer.writerow({'book_name': book_name, 'book_price': book_price, 'book_rate': book_rate})

# %%
data = pd.read_csv('Womens Fiction.csv')
data
# Out:
#                                             book_name  book_price  book_rate
# 0   I Had a Nice Time And Other Lies...: How to fi...       57.36          4
# 1                         Will You Won't You Want Me?       13.86          3
# 2                                      Keep Me Posted       20.46          4
# 3                              Grey (Fifty Shades #4)       48.49          4
# 4                                           Meternity       43.58          3
# 5                                          Some Women       13.73          5
# 6            Shopaholic Ties the Knot (Shopaholic #3)       48.39          5
# 7                              Can You Keep a Secret?       21.94          1
# 8                                       Twenties Girl       42.80          2
# 9                              The Undomestic Goddess       45.75          4
# 10                       The Nanny Diaries (Nanny #1)       52.53          5
# 11   The Devil Wears Prada (The Devil Wears Prada #1)       44.29          1
# 12             Something Borrowed (Darcy & Rachel #1)       48.96          5
# 13                 Something Blue (Darcy & Rachel #2)       54.62          1
# 14                               I've Got Your Number       19.69          1
# 15              The Edge of Reason (Bridget Jones #2)       19.18          4
# 16           Bridget Jones's Diary (Bridget Jones #1)       29.82          1
